# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# imports
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path
import random
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

SEED = 42

os.environ["PYTHONHASHSEED"] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %%
# Reset TensorFlow / Keras state
# tf.keras.backend.clear_session()

# %%
# Read in train and test datasets

# Define paths
drive_dir = Path('/content/drive/MyDrive/Grad_School/SEIS_766 Vision AI/final_project/data/')
csv_path = drive_dir / "ISIC_2020_Training_GroundTruth.csv"

train_dir = drive_dir / 'train'
test_dir = drive_dir / 'test'

print(f'Train dir: {train_dir}')
print(f'Test dir: {test_dir}')
# Out:
# Train dir: /content/drive/MyDrive/Grad_School/SEIS_766 Vision AI/final_project/data/train
# Test dir: /content/drive/MyDrive/Grad_School/SEIS_766 Vision AI/final_project/data/test

# %%
# Read Labels
labels_df = pd.read_csv(csv_path)

# Build filename column
labels_df["filename"] = labels_df["image_name"] + ".jpg"

# Keep only images that are actually in each folder
train_files = {p.name for p in train_dir.glob("*.jpg")}
test_files = {p.name for p in test_dir.glob("*.jpg")}

train_df = labels_df[labels_df["filename"].isin(train_files)].copy()
test_df = labels_df[labels_df["filename"].isin(test_files)].copy()

# Full paths
train_df["filepath"] = train_df["filename"].apply(lambda x: str(train_dir / x))
test_df["filepath"] = test_df["filename"].apply(lambda x: str(test_dir / x))

# Label column
train_df["label"] = train_df["target"].astype("int32")
test_df["label"] = test_df["target"].astype("int32")

assert len(train_df) > 0, "No training images matched the CSV labels."
assert len(test_df) > 0, "No test images matched the CSV labels."

missing_train = train_df.loc[~train_df["filepath"].map(lambda p: Path(p).exists()), "filepath"]
missing_test = test_df.loc[~test_df["filepath"].map(lambda p: Path(p).exists()), "filepath"]

assert missing_train.empty, f'Some training image paths do not exist. Example: {missing_train.iloc[0]}'
assert missing_test.empty, f'Some test image paths do not exist. Example: {missing_test.iloc[0]}'

print("Train class counts:")
print(train_df["label"].value_counts().sort_index())
print("\nTest class counts:")
print(test_df["label"].value_counts().sort_index())
print()
print(train_df[["filepath", "label"]].head())
print(test_df[["filepath", "label"]].head())
# Out:
# Train class counts:
# label
# 0    400
# 1    467
# Name: count, dtype: int64
#
# Test class counts:
# label
# 0    100
# 1    117
# Name: count, dtype: int64
#
#                                               filepath  label
# 83   /content/drive/MyDrive/Grad_School/SEIS_766 Vi...      0
# 91   /content/drive/MyDrive/Grad_School/SEIS_766 Vi...      1
# 223  /content/drive/MyDrive/Grad_School/SEIS_766 Vi...      0
# 235  /content/drive/MyDrive/Grad_School/SEIS_766 Vi...      1
# 348  /content/drive/MyDrive/Grad_School/SEIS_766 Vi...      0
#                                                filepath  label
# 197   /content/drive/MyDrive/Grad_School/SEIS_766 Vi...      0
# 314   /content/drive/MyDrive/Grad_School/SEIS_766 Vi...      1
# 372   /content/drive/MyDrive/Grad_School/SEIS_766 Vi...      0
# 1335  /content/drive/MyDrive/Grad_School/SEIS_766 Vi...      1
# 1351  /content/drive/MyDrive/Grad_School/SEIS_766 Vi...      0

# %%
# Display one example from each class in the training set

# class_names = {0: "Benign", 1: "Malignant"}

# sample_0 = train_df[train_df["label"] == 0].iloc[0]
# sample_1 = train_df[train_df["label"] == 1].iloc[0]

# fig, axes = plt.subplots(1, 2, figsize=(10, 5))

# for ax, sample in zip(axes, [sample_0, sample_1]):
#   img = tf.keras.utils.load_img(sample["filepath"], target_size=IMG_SIZE)
#   ax.imshow(img)
#   ax.set_title(f'Class {sample["label"]}: {class_names[sample["label"]]}')
#   ax.axis("off")

# plt.tight_layout()
# plt.show()

# %%
# Now, turn this into TensorFlow Datasets
IMG_SIZE = (224, 224)
BATCH_SIZE = 32

def load_image(path, label):
  img = tf.io.read_file(path)
  img = tf.image.decode_jpeg(img, channels=3)
  img = tf.image.resize(img, IMG_SIZE)
  img = tf.image.convert_image_dtype(img, tf.float32)
  label = tf.cast(label, tf.float32)  # Cast here if using binary_crossentropy
  return img, label

train_dataset = tf.data.Dataset.from_tensor_slices(
  (train_df["filepath"].values, train_df["label"].values)
).shuffle(len(train_df), seed=SEED, reshuffle_each_iteration=True) \
 .map(load_image) \
 .batch(BATCH_SIZE) \
 .prefetch(tf.data.AUTOTUNE)

test_dataset = tf.data.Dataset.from_tensor_slices(
  (test_df["filepath"].values, test_df["label"].values)
).map(load_image).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

# %%
# training history plotting function
def plot_training_history(history):
    history_dict = history.history
    epochs = range(1, len(history_dict["loss"]) + 1)

    fig, axes = plt.subplots(2, 2, figsize=(12, 8))
    axes = axes.flatten()

    # Loss
    axes[0].plot(epochs, history_dict["loss"])
    axes[0].set_title("Training Loss")
    axes[0].set_xlabel("Epoch")
    axes[0].set_ylabel("Loss")

    # Accuracy
    if "accuracy" in history_dict:
        axes[1].plot(epochs, history_dict["accuracy"])
        axes[1].set_title("Training Accuracy")
        axes[1].set_xlabel("Epoch")
        axes[1].set_ylabel("Accuracy")
    else:
        axes[1].axis("off")

    # AUC
    if "auc" in history_dict:
        axes[2].plot(epochs, history_dict["auc"])
        axes[2].set_title("Training AUC")
        axes[2].set_xlabel("Epoch")
        axes[2].set_ylabel("AUC")
    else:
        axes[2].axis("off")

    # Recall
    if "recall" in history_dict:
        axes[3].plot(epochs, history_dict["recall"])
        axes[3].set_title("Training Recall")
        axes[3].set_xlabel("Epoch")
        axes[3].set_ylabel("Recall")
    else:
        axes[3].axis("off")

    plt.tight_layout()
    plt.show()

# %%
# confusion matrix
def plot_confusion_matrix(y_true, y_pred):
  cm = confusion_matrix(y_true, y_pred)
  disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Benign", "Malignant"])
  disp.plot(cmap='Blues', colorbar=False)
  plt.title("Confusion Matrix")
  plt.show()
  print(cm)

  print(classification_report(y_true, y_pred, target_names=["Benign", "Malignant"]))

# %%
# Build the CNN model
def build_arch1_model(img_size=(224, 224), pooling='avg', dropout_rate=0.3):
  pooling_layer = layers.GlobalAveragePooling2D() if pooling == 'avg' else layers.GlobalMaxPooling2D()

  model = models.Sequential([
    layers.Input(shape=(img_size[0], img_size[1], 3)),
    layers.Conv2D(32, (3, 3), activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64, (3, 3), activation='relu'),
    layers.MaxPooling2D(),
    pooling_layer,
    layers.Dense(128, activation='relu'),
    layers.Dropout(dropout_rate),
    layers.Dense(1, activation='sigmoid')
  ])

  return model

def build_arch2_model(img_size=(224, 224), pooling='avg', dropout_rate=0.3):
  pooling_layer = layers.GlobalAveragePooling2D() if pooling == 'avg' else layers.GlobalMaxPooling2D()

  model = models.Sequential([
    layers.Input(shape=(img_size[0], img_size[1], 3)),
    layers.Conv2D(32, (3, 3), activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64, (3, 3), activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(128, (3, 3), activation='relu'),
    layers.MaxPooling2D(),
    pooling_layer,
    layers.Dense(128, activation='relu'),
    layers.Dropout(dropout_rate),
    layers.Dense(1, activation='sigmoid')
  ])

  return model

def build_arch3_model(img_size=(224, 224), pooling='avg', dropout_rate=0.3):
  pooling_layer = layers.GlobalAveragePooling2D() if pooling == 'avg' else layers.GlobalMaxPooling2D()

  model = models.Sequential([
    layers.Input(shape=(img_size[0], img_size[1], 3)),
    layers.Conv2D(32, (3, 3), activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64, (3, 3), activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(128, (3, 3), activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(256, (3, 3), activation='relu'),
    layers.MaxPooling2D(),
    pooling_layer,
    layers.Dense(128, activation='relu'),
    layers.Dropout(dropout_rate),
    layers.Dense(1, activation='sigmoid')
  ])

  return model

# Choose the architecture to train
POOLING = 'avg' # 'avg' or 'max'

tf.keras.backend.clear_session()

model_1 = build_arch1_model(img_size=IMG_SIZE, pooling=POOLING)
model_2 = build_arch2_model(img_size=IMG_SIZE, pooling=POOLING)
model_3 = build_arch3_model(img_size=IMG_SIZE, pooling=POOLING)

# %% [markdown]
# # Model 1

# %%
model_1.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 109, 109, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 54, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 64)             │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 27,841 (108.75 KB)
#  Trainable params: 27,841 (108.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# compile
model_1.compile(
  optimizer='adam',
  loss='binary_crossentropy',
  # medical classificaitons metrics care more about AUC, Precision, and Recall
  metrics=[
    "accuracy",
    tf.keras.metrics.AUC(name="auc"),
    tf.keras.metrics.Precision(name="precision"),
    tf.keras.metrics.Recall(name="recall"),
  ]
)

# %%
# training
EPOCHS = 35

history = model_1.fit(
  train_dataset,
  epochs=EPOCHS
)

print(history.history.keys())
# Out:
# Epoch 1/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 149ms/step - accuracy: 0.7428 - auc: 0.8141 - loss: 0.5287 - precision: 0.7337 - recall: 0.8201
# Epoch 2/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - accuracy: 0.7532 - auc: 0.8317 - loss: 0.4957 - precision: 0.7288 - recall: 0.8630
# Epoch 3/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.7382 - auc: 0.8289 - loss: 0.5056 - precision: 0.7381 - recall: 0.7966
# Epoch 4/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 150ms/step - accuracy: 0.7416 - auc: 0.8328 - loss: 0.5016 - precision: 0.7120 - recall: 0.8737
# Epoch 5/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - accuracy: 0.7612 - auc: 0.8316 - loss: 0.4930 - precision: 0.7697 - recall: 0.7944
# Epoch 6/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.7659 - auc: 0.8440 - loss: 0.4941 - precision: 0.7409 - recall: 0.8694
# Epoch 7/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.7820 - auc: 0.8563 - loss: 0.4736 - precision: 0.7715 - recall: 0.8458
# Epoch 8/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - accuracy: 0.7647 - auc: 0.8420 - loss: 0.4840 - precision: 0.7505 - recall: 0.8437
# Epoch 9/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 140ms/step - accuracy: 0.7520 - auc: 0.8088 - loss: 0.5181 - precision: 0.7423 - recall: 0.8266
# Epoch 10/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.7774 - auc: 0.8585 - loss: 0.4600 - precision: 0.7718 - recall: 0.8330
# Epoch 11/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 151ms/step - accuracy: 0.7739 - auc: 0.8468 - loss: 0.4717 - precision: 0.7673 - recall: 0.8330
# Epoch 12/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 140ms/step - accuracy: 0.7797 - auc: 0.8532 - loss: 0.4706 - precision: 0.7727 - recall: 0.8373
# Epoch 13/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.7832 - auc: 0.8488 - loss: 0.4730 - precision: 0.7647 - recall: 0.8630
# Epoch 14/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 149ms/step - accuracy: 0.7843 - auc: 0.8629 - loss: 0.4551 - precision: 0.7979 - recall: 0.8030
# Epoch 15/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - accuracy: 0.7647 - auc: 0.8449 - loss: 0.4728 - precision: 0.7387 - recall: 0.8715
# Epoch 16/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 140ms/step - accuracy: 0.7901 - auc: 0.8652 - loss: 0.4532 - precision: 0.7789 - recall: 0.8522
# Epoch 17/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 144ms/step - accuracy: 0.7912 - auc: 0.8638 - loss: 0.4532 - precision: 0.7750 - recall: 0.8630
# Epoch 18/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - accuracy: 0.7878 - auc: 0.8745 - loss: 0.4358 - precision: 0.7780 - recall: 0.8480
# Epoch 19/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.7855 - auc: 0.8650 - loss: 0.4493 - precision: 0.7827 - recall: 0.8330
# Epoch 20/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - accuracy: 0.7947 - auc: 0.8620 - loss: 0.4518 - precision: 0.7691 - recall: 0.8844
# Epoch 21/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 151ms/step - accuracy: 0.7993 - auc: 0.8768 - loss: 0.4331 - precision: 0.7790 - recall: 0.8758
# Epoch 22/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 140ms/step - accuracy: 0.7728 - auc: 0.8488 - loss: 0.4774 - precision: 0.7576 - recall: 0.8501
# Epoch 23/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.7924 - auc: 0.8653 - loss: 0.4506 - precision: 0.7853 - recall: 0.8458
# Epoch 24/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.8016 - auc: 0.8619 - loss: 0.4581 - precision: 0.7788 - recall: 0.8822
# Epoch 25/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 144ms/step - accuracy: 0.7820 - auc: 0.8472 - loss: 0.4883 - precision: 0.7683 - recall: 0.8522
# Epoch 26/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.7785 - auc: 0.8609 - loss: 0.4579 - precision: 0.7523 - recall: 0.8779
# Epoch 27/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 143ms/step - accuracy: 0.7958 - auc: 0.8678 - loss: 0.4487 - precision: 0.7854 - recall: 0.8544
# Epoch 28/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 150ms/step - accuracy: 0.8016 - auc: 0.8824 - loss: 0.4216 - precision: 0.7842 - recall: 0.8715
# Epoch 29/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 143ms/step - accuracy: 0.7762 - auc: 0.8592 - loss: 0.4600 - precision: 0.7630 - recall: 0.8480
# Epoch 30/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - accuracy: 0.7878 - auc: 0.8641 - loss: 0.4561 - precision: 0.7685 - recall: 0.8672
# Epoch 31/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 149ms/step - accuracy: 0.7785 - auc: 0.8562 - loss: 0.4623 - precision: 0.7800 - recall: 0.8201
# Epoch 32/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.7509 - auc: 0.8350 - loss: 0.5194 - precision: 0.7088 - recall: 0.9122
# Epoch 33/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 140ms/step - accuracy: 0.7705 - auc: 0.8595 - loss: 0.4686 - precision: 0.7724 - recall: 0.8137
# Epoch 34/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 147ms/step - accuracy: 0.7774 - auc: 0.8551 - loss: 0.4715 - precision: 0.7655 - recall: 0.8458
# Epoch 35/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.8039 - auc: 0.8702 - loss: 0.4475 - precision: 0.7895 - recall: 0.8672
# Epoch 36/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 140ms/step - accuracy: 0.8108 - auc: 0.8781 - loss: 0.4244 - precision: 0.8048 - recall: 0.8565
# Epoch 37/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.7924 - auc: 0.8787 - loss: 0.4359 - precision: 0.7643 - recall: 0.8887
# Epoch 38/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 151ms/step - accuracy: 0.8108 - auc: 0.8846 - loss: 0.4213 - precision: 0.7988 - recall: 0.8672
# Epoch 39/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - accuracy: 0.8051 - auc: 0.8739 - loss: 0.4305 - precision: 0.7844 - recall: 0.8801
# Epoch 40/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.8051 - auc: 0.8884 - loss: 0.4212 - precision: 0.7922 - recall: 0.8651
# Epoch 41/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 149ms/step - accuracy: 0.7958 - auc: 0.8714 - loss: 0.4356 - precision: 0.7821 - recall: 0.8608
# Epoch 42/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 143ms/step - accuracy: 0.7855 - auc: 0.8773 - loss: 0.4292 - precision: 0.7771 - recall: 0.8437
# Epoch 43/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 143ms/step - accuracy: 0.8074 - auc: 0.8858 - loss: 0.4212 - precision: 0.7918 - recall: 0.8715
# Epoch 44/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.8224 - auc: 0.9038 - loss: 0.3917 - precision: 0.8174 - recall: 0.8630
# Epoch 45/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - accuracy: 0.8005 - auc: 0.8781 - loss: 0.4319 - precision: 0.7928 - recall: 0.8522
# Epoch 46/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.8016 - auc: 0.8725 - loss: 0.4372 - precision: 0.7820 - recall: 0.8758
# Epoch 47/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 144ms/step - accuracy: 0.8108 - auc: 0.8801 - loss: 0.4302 - precision: 0.7988 - recall: 0.8672
# Epoch 48/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 150ms/step - accuracy: 0.8016 - auc: 0.8878 - loss: 0.4189 - precision: 0.7778 - recall: 0.8844
# Epoch 49/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - accuracy: 0.8028 - auc: 0.8915 - loss: 0.4134 - precision: 0.7868 - recall: 0.8694
# Epoch 50/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - accuracy: 0.7555 - auc: 0.8293 - loss: 0.5004 - precision: 0.7457 - recall: 0.8287
# Epoch 51/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - accuracy: 0.7901 - auc: 0.8769 - loss: 0.4314 - precision: 0.7624 - recall: 0.8865
# Epoch 52/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - accuracy: 0.8074 - auc: 0.8880 - loss: 0.4106 - precision: 0.7885 - recall: 0.8779
# Epoch 53/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 140ms/step - accuracy: 0.8085 - auc: 0.8885 - loss: 0.4114 - precision: 0.8040 - recall: 0.8522
# Epoch 54/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.8293 - auc: 0.9012 - loss: 0.3872 - precision: 0.8073 - recall: 0.8972
# Epoch 55/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 149ms/step - accuracy: 0.8143 - auc: 0.8926 - loss: 0.4096 - precision: 0.8048 - recall: 0.8651
# Epoch 56/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - accuracy: 0.8108 - auc: 0.8987 - loss: 0.3953 - precision: 0.8048 - recall: 0.8565
# Epoch 57/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.8201 - auc: 0.8881 - loss: 0.4102 - precision: 0.8008 - recall: 0.8865
# Epoch 58/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 149ms/step - accuracy: 0.8155 - auc: 0.8960 - loss: 0.4045 - precision: 0.8165 - recall: 0.8480
# Epoch 59/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 143ms/step - accuracy: 0.8085 - auc: 0.8863 - loss: 0.4267 - precision: 0.7834 - recall: 0.8908
# Epoch 60/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 140ms/step - accuracy: 0.7809 - auc: 0.8564 - loss: 0.4906 - precision: 0.7700 - recall: 0.8458
# Epoch 61/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 144ms/step - accuracy: 0.7912 - auc: 0.8731 - loss: 0.4520 - precision: 0.7793 - recall: 0.8544
# Epoch 62/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 144ms/step - accuracy: 0.8051 - auc: 0.8867 - loss: 0.4187 - precision: 0.7876 - recall: 0.8737
# Epoch 63/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - accuracy: 0.8097 - auc: 0.8840 - loss: 0.4163 - precision: 0.7949 - recall: 0.8715
# Epoch 64/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.8166 - auc: 0.9015 - loss: 0.3879 - precision: 0.7939 - recall: 0.8908
# Epoch 65/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 152ms/step - accuracy: 0.8143 - auc: 0.8903 - loss: 0.4179 - precision: 0.7931 - recall: 0.8865
# Epoch 66/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.8028 - auc: 0.8830 - loss: 0.4320 - precision: 0.7902 - recall: 0.8630
# Epoch 67/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 140ms/step - accuracy: 0.8189 - auc: 0.9028 - loss: 0.3906 - precision: 0.8027 - recall: 0.8801
# Epoch 68/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - accuracy: 0.8316 - auc: 0.8960 - loss: 0.4013 - precision: 0.8081 - recall: 0.9015
# Epoch 69/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - accuracy: 0.8374 - auc: 0.9029 - loss: 0.3831 - precision: 0.8300 - recall: 0.8779
# Epoch 70/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 143ms/step - accuracy: 0.8224 - auc: 0.9022 - loss: 0.3872 - precision: 0.7970 - recall: 0.8994
# Epoch 71/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 144ms/step - accuracy: 0.8155 - auc: 0.9035 - loss: 0.3876 - precision: 0.8028 - recall: 0.8715
# Epoch 72/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.8339 - auc: 0.9088 - loss: 0.3714 - precision: 0.8124 - recall: 0.8994
# Epoch 73/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.8120 - auc: 0.8856 - loss: 0.4214 - precision: 0.7825 - recall: 0.9015
# Epoch 74/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - accuracy: 0.7405 - auc: 0.8154 - loss: 0.5151 - precision: 0.7093 - recall: 0.8779
# Epoch 75/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 149ms/step - accuracy: 0.8016 - auc: 0.8849 - loss: 0.4190 - precision: 0.8016 - recall: 0.8394
# Epoch 76/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - accuracy: 0.7935 - auc: 0.8727 - loss: 0.4413 - precision: 0.7618 - recall: 0.8972
# Epoch 77/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.8005 - auc: 0.8816 - loss: 0.4303 - precision: 0.7838 - recall: 0.8694
# Epoch 78/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 147ms/step - accuracy: 0.8178 - auc: 0.8923 - loss: 0.4087 - precision: 0.8072 - recall: 0.8694
# Epoch 79/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - accuracy: 0.8189 - auc: 0.8988 - loss: 0.3966 - precision: 0.7981 - recall: 0.8887
# Epoch 80/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.8039 - auc: 0.8853 - loss: 0.4236 - precision: 0.7883 - recall: 0.8694
# Epoch 81/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - accuracy: 0.8166 - auc: 0.8822 - loss: 0.4204 - precision: 0.8008 - recall: 0.8779
# Epoch 82/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 147ms/step - accuracy: 0.8431 - auc: 0.9138 - loss: 0.3646 - precision: 0.8277 - recall: 0.8951
# Epoch 83/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 140ms/step - accuracy: 0.8005 - auc: 0.8719 - loss: 0.4421 - precision: 0.7732 - recall: 0.8908
# Epoch 84/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 143ms/step - accuracy: 0.7797 - auc: 0.8730 - loss: 0.4541 - precision: 0.7717 - recall: 0.8394
# Epoch 85/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 151ms/step - accuracy: 0.8028 - auc: 0.8870 - loss: 0.4116 - precision: 0.7857 - recall: 0.8715
# Epoch 86/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.8108 - auc: 0.8865 - loss: 0.4172 - precision: 0.8086 - recall: 0.8501
# Epoch 87/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - accuracy: 0.8143 - auc: 0.8989 - loss: 0.3967 - precision: 0.8024 - recall: 0.8694
# Epoch 88/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.8224 - auc: 0.9032 - loss: 0.3804 - precision: 0.8015 - recall: 0.8908
# Epoch 89/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - accuracy: 0.8339 - auc: 0.9189 - loss: 0.3555 - precision: 0.8173 - recall: 0.8908
# Epoch 90/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - accuracy: 0.7739 - auc: 0.8431 - loss: 0.4898 - precision: 0.7533 - recall: 0.8630
# Epoch 91/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - accuracy: 0.8028 - auc: 0.8918 - loss: 0.4137 - precision: 0.7902 - recall: 0.8630
# Epoch 92/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - accuracy: 0.8131 - auc: 0.8900 - loss: 0.4172 - precision: 0.7984 - recall: 0.8737
# Epoch 93/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - accuracy: 0.8212 - auc: 0.9046 - loss: 0.3865 - precision: 0.8145 - recall: 0.8651
# Epoch 94/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 140ms/step - accuracy: 0.8339 - auc: 0.9100 - loss: 0.3742 - precision: 0.8289 - recall: 0.8715
# Epoch 95/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 151ms/step - accuracy: 0.8351 - auc: 0.9070 - loss: 0.3802 - precision: 0.8320 - recall: 0.8694
# Epoch 96/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - accuracy: 0.7855 - auc: 0.8761 - loss: 0.4493 - precision: 0.7569 - recall: 0.8865
# Epoch 97/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - accuracy: 0.8166 - auc: 0.8895 - loss: 0.4107 - precision: 0.8143 - recall: 0.8544
# Epoch 98/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - accuracy: 0.8189 - auc: 0.8955 - loss: 0.3996 - precision: 0.7947 - recall: 0.8951
# Epoch 99/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - accuracy: 0.8316 - auc: 0.9100 - loss: 0.3750 - precision: 0.8166 - recall: 0.8865
# Epoch 100/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 140ms/step - accuracy: 0.8281 - auc: 0.9094 - loss: 0.3748 - precision: 0.8272 - recall: 0.8608
# dict_keys(['accuracy', 'auc', 'loss', 'precision', 'recall'])

# %%
# evaluate
results_1 = model_1.evaluate(test_dataset, return_dict=True)
results_1
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 135ms/step - accuracy: 0.7465 - auc: 0.7679 - loss: 0.6969 - precision: 0.7348 - recall: 0.8291
# {'accuracy': 0.7465437650680542,
#  'auc': 0.7679060697555542,
#  'loss': 0.69685298204422,
#  'precision': 0.7348484992980957,
#  'recall': 0.8290598392486572}

# %%
# plot
plot_training_history(history)

# %%
# predict
threshold = 0.5

y_prob_1 = model_1.predict(test_dataset)
y_pred_1 = (y_prob_1 > threshold).astype(int)
y_true_1 = test_df["label"].values
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 133ms/step

# %%
plot_confusion_matrix(y_true_1, y_pred_1)
# Out:
# [[65 35]
#  [20 97]]
#               precision    recall  f1-score   support
#
#       Benign       0.76      0.65      0.70       100
#    Malignant       0.73      0.83      0.78       117
#
#     accuracy                           0.75       217
#    macro avg       0.75      0.74      0.74       217
# weighted avg       0.75      0.75      0.74       217

# %% [markdown]
# # Model 2

# %%
model_2.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)               │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 109, 109, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 54, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 52, 52, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 26, 26, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 329,669 (1.26 MB)
#  Trainable params: 109,889 (429.25 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 219,780 (858.52 KB)

# %%
#compile
model_2.compile(
  optimizer='adam',
  loss='binary_crossentropy',
  # medical classificaitons metrics care more about AUC, Precision, and Recall
  metrics=[
    "accuracy",
    tf.keras.metrics.AUC(name="auc"),
    tf.keras.metrics.Precision(name="precision"),
    tf.keras.metrics.Recall(name="recall"),
  ]
)

# %%
# training
EPOCHS = 45

history_2 = model_2.fit(
  train_dataset,
  epochs=EPOCHS
)

print(history_2.history.keys())
# Out:
# Epoch 1/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.8824 - auc: 0.9586 - loss: 0.2565 - precision: 0.8810 - recall: 0.9036
# Epoch 2/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.8997 - auc: 0.9657 - loss: 0.2396 - precision: 0.8975 - recall: 0.9186
# Epoch 3/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 152ms/step - accuracy: 0.8501 - auc: 0.9453 - loss: 0.2975 - precision: 0.8624 - recall: 0.8587
# Epoch 4/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.8973 - auc: 0.9698 - loss: 0.2255 - precision: 0.9004 - recall: 0.9101
# Epoch 5/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 140ms/step - accuracy: 0.8800 - auc: 0.9514 - loss: 0.2804 - precision: 0.8727 - recall: 0.9101
# Epoch 6/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 147ms/step - accuracy: 0.8731 - auc: 0.9547 - loss: 0.2729 - precision: 0.8774 - recall: 0.8887
# Epoch 7/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 143ms/step - accuracy: 0.9008 - auc: 0.9682 - loss: 0.2331 - precision: 0.9114 - recall: 0.9036
# Epoch 8/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - accuracy: 0.9020 - auc: 0.9664 - loss: 0.2430 - precision: 0.9170 - recall: 0.8994
# Epoch 9/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 143ms/step - accuracy: 0.8997 - auc: 0.9689 - loss: 0.2282 - precision: 0.9060 - recall: 0.9079
# Epoch 10/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - accuracy: 0.9066 - auc: 0.9756 - loss: 0.2059 - precision: 0.9106 - recall: 0.9165
# Epoch 11/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - accuracy: 0.8985 - auc: 0.9686 - loss: 0.2258 - precision: 0.9041 - recall: 0.9079
# Epoch 12/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.9043 - auc: 0.9711 - loss: 0.2167 - precision: 0.9034 - recall: 0.9208
# Epoch 13/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - accuracy: 0.8893 - auc: 0.9674 - loss: 0.2278 - precision: 0.8793 - recall: 0.9208
# Epoch 14/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - accuracy: 0.9054 - auc: 0.9690 - loss: 0.2262 - precision: 0.9002 - recall: 0.9272
# Epoch 15/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.8939 - auc: 0.9726 - loss: 0.2110 - precision: 0.9015 - recall: 0.9015
# Epoch 16/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.8824 - auc: 0.9620 - loss: 0.2452 - precision: 0.8842 - recall: 0.8994
# Epoch 17/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 143ms/step - accuracy: 0.8639 - auc: 0.9412 - loss: 0.3240 - precision: 0.8598 - recall: 0.8929
# Epoch 18/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 143ms/step - accuracy: 0.8420 - auc: 0.9316 - loss: 0.3335 - precision: 0.8526 - recall: 0.8544
# Epoch 19/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 144ms/step - accuracy: 0.8800 - auc: 0.9520 - loss: 0.2788 - precision: 0.8937 - recall: 0.8822
# Epoch 20/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 150ms/step - accuracy: 0.8835 - auc: 0.9625 - loss: 0.2519 - precision: 0.8813 - recall: 0.9058
# Epoch 21/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 139ms/step - accuracy: 0.9089 - auc: 0.9686 - loss: 0.2363 - precision: 0.9076 - recall: 0.9251
# Epoch 22/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 139ms/step - accuracy: 0.8997 - auc: 0.9670 - loss: 0.2303 - precision: 0.8958 - recall: 0.9208
# Epoch 23/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 150ms/step - accuracy: 0.8754 - auc: 0.9548 - loss: 0.2712 - precision: 0.8795 - recall: 0.8908
# Epoch 24/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 140ms/step - accuracy: 0.8547 - auc: 0.9377 - loss: 0.3212 - precision: 0.8589 - recall: 0.8737
# Epoch 25/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 140ms/step - accuracy: 0.8973 - auc: 0.9649 - loss: 0.2409 - precision: 0.8938 - recall: 0.9186
# Epoch 26/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - accuracy: 0.9054 - auc: 0.9700 - loss: 0.2241 - precision: 0.9087 - recall: 0.9165
# Epoch 27/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - accuracy: 0.8962 - auc: 0.9646 - loss: 0.2398 - precision: 0.8919 - recall: 0.9186
# Epoch 28/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - accuracy: 0.8824 - auc: 0.9642 - loss: 0.2397 - precision: 0.8891 - recall: 0.8929
# Epoch 29/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 144ms/step - accuracy: 0.9146 - auc: 0.9743 - loss: 0.2073 - precision: 0.9085 - recall: 0.9358
# Epoch 30/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 149ms/step - accuracy: 0.8893 - auc: 0.9635 - loss: 0.2412 - precision: 0.8905 - recall: 0.9058
# Epoch 31/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 143ms/step - accuracy: 0.8881 - auc: 0.9629 - loss: 0.2553 - precision: 0.8745 - recall: 0.9251
# Epoch 32/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.8997 - auc: 0.9683 - loss: 0.2267 - precision: 0.8926 - recall: 0.9251
# Epoch 33/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 151ms/step - accuracy: 0.9112 - auc: 0.9743 - loss: 0.2088 - precision: 0.9131 - recall: 0.9229
# Epoch 34/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 140ms/step - accuracy: 0.9227 - auc: 0.9775 - loss: 0.2002 - precision: 0.9149 - recall: 0.9443
# Epoch 35/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 143ms/step - accuracy: 0.9193 - auc: 0.9772 - loss: 0.1947 - precision: 0.9251 - recall: 0.9251
# Epoch 36/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.9089 - auc: 0.9774 - loss: 0.1951 - precision: 0.9128 - recall: 0.9186
# Epoch 37/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 144ms/step - accuracy: 0.8893 - auc: 0.9671 - loss: 0.2312 - precision: 0.8905 - recall: 0.9058
# Epoch 38/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 139ms/step - accuracy: 0.8973 - auc: 0.9652 - loss: 0.2395 - precision: 0.9038 - recall: 0.9058
# Epoch 39/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.8258 - auc: 0.8967 - loss: 0.8521 - precision: 0.8333 - recall: 0.8458
# Epoch 40/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 149ms/step - accuracy: 0.7174 - auc: 0.8253 - loss: 0.5590 - precision: 0.6975 - recall: 0.8394
# Epoch 41/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.8028 - auc: 0.8842 - loss: 0.4397 - precision: 0.7824 - recall: 0.8779
# Epoch 42/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 143ms/step - accuracy: 0.8085 - auc: 0.9047 - loss: 0.3893 - precision: 0.7845 - recall: 0.8887
# Epoch 43/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 150ms/step - accuracy: 0.8397 - auc: 0.9179 - loss: 0.3666 - precision: 0.8431 - recall: 0.8630
# Epoch 44/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.8281 - auc: 0.9142 - loss: 0.3681 - precision: 0.8245 - recall: 0.8651
# Epoch 45/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 144ms/step - accuracy: 0.8304 - auc: 0.9194 - loss: 0.3598 - precision: 0.8320 - recall: 0.8587
# dict_keys(['accuracy', 'auc', 'loss', 'precision', 'recall'])

# %%
# evaluate
results_2 = model_2.evaluate(test_dataset, return_dict=True)
results_2
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 130ms/step - accuracy: 0.7327 - auc: 0.7846 - loss: 1.1116 - precision: 0.7153 - recall: 0.8376
# {'accuracy': 0.7327188849449158,
#  'auc': 0.7845726609230042,
#  'loss': 1.1115912199020386,
#  'precision': 0.7153284549713135,
#  'recall': 0.8376068472862244}

# %%
# plot
plot_training_history(history_2)

# %%
# predict
threshold = 0.5

y_prob_2 = model_2.predict(test_dataset)
y_pred_2 = (y_prob_2 > threshold).astype(int)
y_true_2 = test_df["label"].values
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step

# %%
plot_confusion_matrix(y_true_2, y_pred_2)
# Out:
# [[61 39]
#  [19 98]]
#               precision    recall  f1-score   support
#
#       Benign       0.76      0.61      0.68       100
#    Malignant       0.72      0.84      0.77       117
#
#     accuracy                           0.73       217
#    macro avg       0.74      0.72      0.72       217
# weighted avg       0.74      0.73      0.73       217

# %% [markdown]
# # Model 3

# %%
model_3.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_5 (Conv2D)               │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 109, 109, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 54, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 52, 52, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 26, 26, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 24, 24, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 12, 12, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_2      │ (None, 256)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 421,441 (1.61 MB)
#  Trainable params: 421,441 (1.61 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
#compile
model_3.compile(
  optimizer='adam',
  loss='binary_crossentropy',
  # medical classificaitons metrics care more about AUC, Precision, and Recall
  metrics=[
    "accuracy",
    tf.keras.metrics.AUC(name="auc"),
    tf.keras.metrics.Precision(name="precision"),
    tf.keras.metrics.Recall(name="recall"),
  ]
)

# %%
# training
EPOCHS = 45

history_3 = model_3.fit(
  train_dataset,
  epochs=EPOCHS
)

print(history_3.history.keys())
# Out:
# Epoch 1/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 304ms/step - accuracy: 0.5179 - auc: 0.5137 - loss: 1.9590 - precision: 0.5514 - recall: 0.5632
# Epoch 2/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 140ms/step - accuracy: 0.5283 - auc: 0.5490 - loss: 0.7100 - precision: 0.5671 - recall: 0.5246
# Epoch 3/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 144ms/step - accuracy: 0.5144 - auc: 0.5251 - loss: 0.7144 - precision: 0.5548 - recall: 0.4989
# Epoch 4/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 147ms/step - accuracy: 0.5467 - auc: 0.5522 - loss: 0.6979 - precision: 0.5737 - recall: 0.6167
# Epoch 5/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.5709 - auc: 0.5941 - loss: 0.6816 - precision: 0.6077 - recall: 0.5739
# Epoch 6/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 140ms/step - accuracy: 0.5629 - auc: 0.6032 - loss: 0.6880 - precision: 0.5995 - recall: 0.5675
# Epoch 7/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 151ms/step - accuracy: 0.5813 - auc: 0.6285 - loss: 0.6736 - precision: 0.6327 - recall: 0.5310
# Epoch 8/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - accuracy: 0.5963 - auc: 0.6377 - loss: 0.6619 - precision: 0.6242 - recall: 0.6296
# Epoch 9/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.5848 - auc: 0.6242 - loss: 0.6692 - precision: 0.5718 - recall: 0.9122
# Epoch 10/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 150ms/step - accuracy: 0.5802 - auc: 0.6191 - loss: 0.6769 - precision: 0.6157 - recall: 0.5867
# Epoch 11/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 143ms/step - accuracy: 0.6240 - auc: 0.6539 - loss: 0.6549 - precision: 0.6436 - recall: 0.6767
# Epoch 12/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 140ms/step - accuracy: 0.6228 - auc: 0.6601 - loss: 0.6425 - precision: 0.6316 - recall: 0.7195
# Epoch 13/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 144ms/step - accuracy: 0.5640 - auc: 0.5993 - loss: 0.6894 - precision: 0.5899 - recall: 0.6253
# Epoch 14/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 150ms/step - accuracy: 0.5894 - auc: 0.6110 - loss: 0.6828 - precision: 0.6209 - recall: 0.6103
# Epoch 15/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - accuracy: 0.5732 - auc: 0.5661 - loss: 0.6835 - precision: 0.5826 - recall: 0.7323
# Epoch 16/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.6217 - auc: 0.6409 - loss: 0.6656 - precision: 0.6457 - recall: 0.6595
# Epoch 17/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - accuracy: 0.5952 - auc: 0.6363 - loss: 0.6604 - precision: 0.6218 - recall: 0.6338
# Epoch 18/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - accuracy: 0.6275 - auc: 0.6516 - loss: 0.6555 - precision: 0.6406 - recall: 0.7024
# Epoch 19/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 140ms/step - accuracy: 0.6171 - auc: 0.6689 - loss: 0.6442 - precision: 0.6199 - recall: 0.7473
# Epoch 20/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - accuracy: 0.5802 - auc: 0.6060 - loss: 0.6819 - precision: 0.5918 - recall: 0.7109
# Epoch 21/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 144ms/step - accuracy: 0.5444 - auc: 0.6001 - loss: 0.6890 - precision: 0.5531 - recall: 0.8030
# Epoch 22/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.6044 - auc: 0.6244 - loss: 0.8430 - precision: 0.6088 - recall: 0.7430
# Epoch 23/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 144ms/step - accuracy: 0.5617 - auc: 0.5691 - loss: 0.6956 - precision: 0.5848 - recall: 0.6424
# Epoch 24/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - accuracy: 0.5571 - auc: 0.6068 - loss: 0.6741 - precision: 0.5924 - recall: 0.5696
# Epoch 25/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.5663 - auc: 0.5873 - loss: 0.6801 - precision: 0.5762 - recall: 0.7366
# Epoch 26/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - accuracy: 0.5686 - auc: 0.6050 - loss: 0.6671 - precision: 0.5850 - recall: 0.6852
# Epoch 27/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 151ms/step - accuracy: 0.5686 - auc: 0.6008 - loss: 0.6867 - precision: 0.6148 - recall: 0.5332
# Epoch 28/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 144ms/step - accuracy: 0.5744 - auc: 0.5964 - loss: 0.6764 - precision: 0.5740 - recall: 0.8137
# Epoch 29/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 140ms/step - accuracy: 0.5894 - auc: 0.6304 - loss: 0.6686 - precision: 0.6337 - recall: 0.5632
# Epoch 30/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 147ms/step - accuracy: 0.6228 - auc: 0.6542 - loss: 0.6503 - precision: 0.6122 - recall: 0.8180
# Epoch 31/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 143ms/step - accuracy: 0.6182 - auc: 0.6460 - loss: 0.6497 - precision: 0.6160 - recall: 0.7730
# Epoch 32/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 143ms/step - accuracy: 0.6159 - auc: 0.6436 - loss: 0.6525 - precision: 0.6245 - recall: 0.7195
# Epoch 33/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 144ms/step - accuracy: 0.5444 - auc: 0.5682 - loss: 0.6827 - precision: 0.5503 - recall: 0.8437
# Epoch 34/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.5386 - auc: 0.5647 - loss: 0.6835 - precision: 0.5390 - recall: 0.9914
# Epoch 35/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.5375 - auc: 0.6313 - loss: 0.6900 - precision: 0.5382 - recall: 0.9957
# Epoch 36/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 143ms/step - accuracy: 0.5386 - auc: 0.6218 - loss: 0.6708 - precision: 0.5386 - recall: 1.0000
# Epoch 37/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 150ms/step - accuracy: 0.5375 - auc: 0.5905 - loss: 0.6745 - precision: 0.5381 - recall: 0.9979
# Epoch 38/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 139ms/step - accuracy: 0.5444 - auc: 0.5948 - loss: 0.6832 - precision: 0.5463 - recall: 0.9101
# Epoch 39/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.5652 - auc: 0.6057 - loss: 0.6714 - precision: 0.5645 - recall: 0.8437
# Epoch 40/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 147ms/step - accuracy: 0.5836 - auc: 0.6190 - loss: 0.6761 - precision: 0.5971 - recall: 0.6981
# Epoch 41/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - accuracy: 0.5998 - auc: 0.6378 - loss: 0.6620 - precision: 0.6014 - recall: 0.7623
# Epoch 42/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - accuracy: 0.5894 - auc: 0.6185 - loss: 0.6697 - precision: 0.6154 - recall: 0.6338
# Epoch 43/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - accuracy: 0.5790 - auc: 0.6198 - loss: 0.6703 - precision: 0.5951 - recall: 0.6831
# Epoch 44/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 147ms/step - accuracy: 0.6067 - auc: 0.6539 - loss: 0.6533 - precision: 0.6275 - recall: 0.6638
# Epoch 45/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 143ms/step - accuracy: 0.5559 - auc: 0.5706 - loss: 0.7223 - precision: 0.6068 - recall: 0.4989
# dict_keys(['accuracy', 'auc', 'loss', 'precision', 'recall'])

# %%
# evaluate
results_3 = model_3.evaluate(test_dataset, return_dict=True)
results_3
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 459ms/step - accuracy: 0.4793 - auc: 0.6541 - loss: 0.6958 - precision: 0.6667 - recall: 0.0684
# {'accuracy': 0.47926267981529236,
#  'auc': 0.654059886932373,
#  'loss': 0.6957703828811646,
#  'precision': 0.6666666865348816,
#  'recall': 0.0683760717511177}

# %%
# plot
plot_training_history(history_3)

# %%
# predict
threshold = 0.5

y_prob_3 = model_3.predict(test_dataset)
y_pred_3 = (y_prob_3 > threshold).astype(int)
y_true_3 = test_df["label"].values
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 182ms/step

# %%
plot_confusion_matrix(y_true_3, y_pred_3)
# Out:
# [[ 96   4]
#  [109   8]]
#               precision    recall  f1-score   support
#
#       Benign       0.47      0.96      0.63       100
#    Malignant       0.67      0.07      0.12       117
#
#     accuracy                           0.48       217
#    macro avg       0.57      0.51      0.38       217
# weighted avg       0.58      0.48      0.36       217

# %% [markdown]
# # Save Models

# %%
# Save the model to google drive
model_dir = Path("/content/drive/MyDrive/Grad_School/SEIS_766 Vision AI/final_project/models")
model_dir.mkdir(parents=True, exist_ok=True)

# model_1_path = model_dir / "melanoma_cnn_arch1_35epochs.keras"
# model_1.save(model_1_path)

# model_2_path = model_dir / "melanoma_cnn_arch2_45epochs.keras"
# model_2.save(model_2_path)

# %% [markdown]
# ## Loading the model
#
# Another user can load the saved model with:
#
# ```python
# import tensorflow as tf
#
# model = tf.keras.models.load_model(
#     "/content/drive/MyDrive/.../melanoma_cnn_arch1_35epochs.keras"
# )
# ```
#
# To use the model correctly, images should be preprocessed the same way they were during training:
#
# - resize to `224 x 224`
# - convert to `float32`
# - scale pixel values to `[0, 1]`
# - add a batch dimension before prediction
#
# Example for predicting one image:
#
# ```python
# import tensorflow as tf
# import numpy as np
#
# IMG_SIZE = (224, 224)
# THRESHOLD = 0.5
#
# def preprocess_image(image_path):
#     img = tf.keras.utils.load_img(image_path, target_size=IMG_SIZE)
#     img = tf.keras.utils.img_to_array(img)
#     img = img.astype("float32") / 255.0
#     img = np.expand_dims(img, axis=0)
#     return img
#
# model = tf.keras.models.load_model(
#     "/content/drive/MyDrive/.../melanoma_cnn_arch1_35epochs.keras"
# )
#
# image_path = "example.jpg"
# image_tensor = preprocess_image(image_path)
#
# prediction = model.predict(image_tensor, verbose=0)[0][0]
# predicted_label = "Malignant" if prediction >= THRESHOLD else "Benign"
#
# print(f"Malignant probability: {prediction:.4f}")
# print(f"Predicted label: {predicted_label}")
# ```
#
# Interpretation:
#
# - output close to `1.0` means the model predicts the image is more likely malignant
# - output close to `0.0` means the model predicts the image is more likely benign
# - this notebook used a threshold of `0.5` for classification
