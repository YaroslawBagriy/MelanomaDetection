# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# imports
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path
import random
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

SEED = 42

os.environ["PYTHONHASHSEED"] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %%
# Reset TensorFlow / Keras state
# tf.keras.backend.clear_session()

# %%
# Read in train and test datasets

# Define paths
drive_dir = Path('/content/drive/MyDrive/Grad_School/SEIS_766 Vision AI/final_project/data/')
csv_path = drive_dir / "ISIC_2020_Training_GroundTruth.csv"

train_dir = drive_dir / 'train'
test_dir = drive_dir / 'test'

print(f'Train dir: {train_dir}')
print(f'Test dir: {test_dir}')
# Out:
# Train dir: /content/drive/MyDrive/Grad_School/SEIS_766 Vision AI/final_project/data/train
# Test dir: /content/drive/MyDrive/Grad_School/SEIS_766 Vision AI/final_project/data/test

# %%
# Read Labels
labels_df = pd.read_csv(csv_path)

# Build filename column
labels_df["filename"] = labels_df["image_name"] + ".jpg"

# Keep only images that are actually in each folder
train_files = {p.name for p in train_dir.glob("*.jpg")}
test_files = {p.name for p in test_dir.glob("*.jpg")}

train_df = labels_df[labels_df["filename"].isin(train_files)].copy()
test_df = labels_df[labels_df["filename"].isin(test_files)].copy()

# Full paths
train_df["filepath"] = train_df["filename"].apply(lambda x: str(train_dir / x))
test_df["filepath"] = test_df["filename"].apply(lambda x: str(test_dir / x))

# Label column
train_df["label"] = train_df["target"].astype("int32")
test_df["label"] = test_df["target"].astype("int32")

assert len(train_df) > 0, "No training images matched the CSV labels."
assert len(test_df) > 0, "No test images matched the CSV labels."

missing_train = train_df.loc[~train_df["filepath"].map(lambda p: Path(p).exists()), "filepath"]
missing_test = test_df.loc[~test_df["filepath"].map(lambda p: Path(p).exists()), "filepath"]

assert missing_train.empty, f'Some training image paths do not exist. Example: {missing_train.iloc[0]}'
assert missing_test.empty, f'Some test image paths do not exist. Example: {missing_test.iloc[0]}'

print("Train class counts:")
print(train_df["label"].value_counts().sort_index())
print("\nTest class counts:")
print(test_df["label"].value_counts().sort_index())
print()
print(train_df[["filepath", "label"]].head())
print(test_df[["filepath", "label"]].head())
# Out:
# Train class counts:
# label
# 0    400
# 1    467
# Name: count, dtype: int64
#
# Test class counts:
# label
# 0    100
# 1    117
# Name: count, dtype: int64
#
#                                               filepath  label
# 83   /content/drive/MyDrive/Grad_School/SEIS_766 Vi...      0
# 91   /content/drive/MyDrive/Grad_School/SEIS_766 Vi...      1
# 223  /content/drive/MyDrive/Grad_School/SEIS_766 Vi...      0
# 235  /content/drive/MyDrive/Grad_School/SEIS_766 Vi...      1
# 348  /content/drive/MyDrive/Grad_School/SEIS_766 Vi...      0
#                                                filepath  label
# 197   /content/drive/MyDrive/Grad_School/SEIS_766 Vi...      0
# 314   /content/drive/MyDrive/Grad_School/SEIS_766 Vi...      1
# 372   /content/drive/MyDrive/Grad_School/SEIS_766 Vi...      0
# 1335  /content/drive/MyDrive/Grad_School/SEIS_766 Vi...      1
# 1351  /content/drive/MyDrive/Grad_School/SEIS_766 Vi...      0

# %%
# Display one example from each class in the training set

# class_names = {0: "Benign", 1: "Malignant"}

# sample_0 = train_df[train_df["label"] == 0].iloc[0]
# sample_1 = train_df[train_df["label"] == 1].iloc[0]

# fig, axes = plt.subplots(1, 2, figsize=(10, 5))

# for ax, sample in zip(axes, [sample_0, sample_1]):
#   img = tf.keras.utils.load_img(sample["filepath"], target_size=IMG_SIZE)
#   ax.imshow(img)
#   ax.set_title(f'Class {sample["label"]}: {class_names[sample["label"]]}')
#   ax.axis("off")

# plt.tight_layout()
# plt.show()

# %%
# Now, turn this into TensorFlow Datasets
IMG_SIZE = (224, 224)
BATCH_SIZE = 32

def load_image(path, label):
  img = tf.io.read_file(path)
  img = tf.image.decode_jpeg(img, channels=3)
  img = tf.image.resize(img, IMG_SIZE)
  img = tf.image.convert_image_dtype(img, tf.float32)
  label = tf.cast(label, tf.float32)  # Cast here if using binary_crossentropy
  return img, label

train_dataset = tf.data.Dataset.from_tensor_slices(
  (train_df["filepath"].values, train_df["label"].values)
).shuffle(len(train_df), seed=SEED, reshuffle_each_iteration=True) \
 .map(load_image) \
 .batch(BATCH_SIZE) \
 .prefetch(tf.data.AUTOTUNE)

test_dataset = tf.data.Dataset.from_tensor_slices(
  (test_df["filepath"].values, test_df["label"].values)
).map(load_image).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

# %%
# training history plotting function
def plot_training_history(history):
    history_dict = history.history
    epochs = range(1, len(history_dict["loss"]) + 1)

    fig, axes = plt.subplots(2, 2, figsize=(12, 8))
    axes = axes.flatten()

    # Loss
    axes[0].plot(epochs, history_dict["loss"])
    axes[0].set_title("Training Loss")
    axes[0].set_xlabel("Epoch")
    axes[0].set_ylabel("Loss")

    # Accuracy
    if "accuracy" in history_dict:
        axes[1].plot(epochs, history_dict["accuracy"])
        axes[1].set_title("Training Accuracy")
        axes[1].set_xlabel("Epoch")
        axes[1].set_ylabel("Accuracy")
    else:
        axes[1].axis("off")

    # AUC
    if "auc" in history_dict:
        axes[2].plot(epochs, history_dict["auc"])
        axes[2].set_title("Training AUC")
        axes[2].set_xlabel("Epoch")
        axes[2].set_ylabel("AUC")
    else:
        axes[2].axis("off")

    # Recall
    if "recall" in history_dict:
        axes[3].plot(epochs, history_dict["recall"])
        axes[3].set_title("Training Recall")
        axes[3].set_xlabel("Epoch")
        axes[3].set_ylabel("Recall")
    else:
        axes[3].axis("off")

    plt.tight_layout()
    plt.show()

# %%
# confusion matrix
def plot_confusion_matrix(y_true, y_pred):
  cm = confusion_matrix(y_true, y_pred)
  disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Benign", "Malignant"])
  disp.plot(cmap='Blues', colorbar=False)
  plt.title("Confusion Matrix")
  plt.show()
  print(cm)

  print(classification_report(y_true, y_pred, target_names=["Benign", "Malignant"]))

# %%
# Build the CNN model
def build_arch1_model(img_size=(224, 224), pooling='avg', dropout_rate=0.3):
  pooling_layer = layers.GlobalAveragePooling2D() if pooling == 'avg' else layers.GlobalMaxPooling2D()

  model = models.Sequential([
    layers.Input(shape=(img_size[0], img_size[1], 3)),
    layers.Conv2D(32, (3, 3), activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64, (3, 3), activation='relu'),
    layers.MaxPooling2D(),
    pooling_layer,
    layers.Dense(128, activation='relu'),
    layers.Dropout(dropout_rate),
    layers.Dense(1, activation='sigmoid')
  ])

  return model

def build_arch2_model(img_size=(224, 224), pooling='avg', dropout_rate=0.3):
  pooling_layer = layers.GlobalAveragePooling2D() if pooling == 'avg' else layers.GlobalMaxPooling2D()

  model = models.Sequential([
    layers.Input(shape=(img_size[0], img_size[1], 3)),
    layers.Conv2D(32, (3, 3), activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64, (3, 3), activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(128, (3, 3), activation='relu'),
    layers.MaxPooling2D(),
    pooling_layer,
    layers.Dense(128, activation='relu'),
    layers.Dropout(dropout_rate),
    layers.Dense(1, activation='sigmoid')
  ])

  return model

# Choose the architecture to train
POOLING = 'avg'         # 'avg' or 'max'

tf.keras.backend.clear_session()

model_1 = build_arch1_model(img_size=IMG_SIZE, pooling=POOLING)
model_2 = build_arch2_model(img_size=IMG_SIZE, pooling=POOLING)

# %% [markdown]
# # Model 1

# %%
model_1.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 109, 109, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 54, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 64)             │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 27,841 (108.75 KB)
#  Trainable params: 27,841 (108.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# compile
model_1.compile(
  optimizer='adam',
  loss='binary_crossentropy',
  # medical classificaitons metrics care more about AUC, Precision, and Recall
  metrics=[
    "accuracy",
    tf.keras.metrics.AUC(name="auc"),
    tf.keras.metrics.Precision(name="precision"),
    tf.keras.metrics.Recall(name="recall"),
  ]
)

# %%
# training
EPOCHS = 35

history = model_1.fit(
  train_dataset,
  epochs=EPOCHS
)

print(history.history.keys())
# Out:
# Epoch 1/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 69s 2s/step - accuracy: 0.5433 - auc: 0.5572 - loss: 1.3553 - precision: 0.5851 - recall: 0.5225
# Epoch 2/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - accuracy: 0.5848 - auc: 0.6051 - loss: 0.6988 - precision: 0.6161 - recall: 0.6081
# Epoch 3/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 144ms/step - accuracy: 0.5848 - auc: 0.6151 - loss: 0.6874 - precision: 0.6161 - recall: 0.6081
# Epoch 4/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.6032 - auc: 0.6473 - loss: 0.6625 - precision: 0.6407 - recall: 0.5996
# Epoch 5/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 147ms/step - accuracy: 0.6171 - auc: 0.6541 - loss: 0.6579 - precision: 0.6353 - recall: 0.6788
# Epoch 6/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - accuracy: 0.6286 - auc: 0.6668 - loss: 0.6509 - precision: 0.6477 - recall: 0.6809
# Epoch 7/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 140ms/step - accuracy: 0.6228 - auc: 0.6553 - loss: 0.6603 - precision: 0.6477 - recall: 0.6574
# Epoch 8/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 150ms/step - accuracy: 0.6240 - auc: 0.6507 - loss: 0.6571 - precision: 0.6275 - recall: 0.7430
# Epoch 9/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.6367 - auc: 0.6717 - loss: 0.6644 - precision: 0.6610 - recall: 0.6681
# Epoch 10/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 139ms/step - accuracy: 0.6378 - auc: 0.6883 - loss: 0.6348 - precision: 0.6638 - recall: 0.6638
# Epoch 11/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 147ms/step - accuracy: 0.6390 - auc: 0.6836 - loss: 0.6444 - precision: 0.6624 - recall: 0.6724
# Epoch 12/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 143ms/step - accuracy: 0.6667 - auc: 0.6973 - loss: 0.6440 - precision: 0.6918 - recall: 0.6874
# Epoch 13/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 139ms/step - accuracy: 0.6713 - auc: 0.7084 - loss: 0.6209 - precision: 0.6770 - recall: 0.7452
# Epoch 14/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 143ms/step - accuracy: 0.6390 - auc: 0.6717 - loss: 0.6588 - precision: 0.6674 - recall: 0.6574
# Epoch 15/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - accuracy: 0.6528 - auc: 0.7004 - loss: 0.6238 - precision: 0.6627 - recall: 0.7238
# Epoch 16/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.6897 - auc: 0.7288 - loss: 0.6188 - precision: 0.7097 - recall: 0.7173
# Epoch 17/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.6724 - auc: 0.7256 - loss: 0.6129 - precision: 0.6777 - recall: 0.7473
# Epoch 18/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 150ms/step - accuracy: 0.6621 - auc: 0.7038 - loss: 0.6304 - precision: 0.6740 - recall: 0.7216
# Epoch 19/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.6817 - auc: 0.7395 - loss: 0.5987 - precision: 0.7072 - recall: 0.6981
# Epoch 20/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.7047 - auc: 0.7509 - loss: 0.5984 - precision: 0.7106 - recall: 0.7623
# Epoch 21/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - accuracy: 0.6205 - auc: 0.6659 - loss: 0.6512 - precision: 0.6202 - recall: 0.7623
# Epoch 22/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - accuracy: 0.6505 - auc: 0.7183 - loss: 0.6167 - precision: 0.6414 - recall: 0.7966
# Epoch 23/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - accuracy: 0.6782 - auc: 0.7338 - loss: 0.6021 - precision: 0.6815 - recall: 0.7559
# Epoch 24/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 143ms/step - accuracy: 0.7036 - auc: 0.7433 - loss: 0.5997 - precision: 0.7134 - recall: 0.7516
# Epoch 25/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 151ms/step - accuracy: 0.6805 - auc: 0.7432 - loss: 0.6049 - precision: 0.6759 - recall: 0.7816
# Epoch 26/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 140ms/step - accuracy: 0.6886 - auc: 0.7410 - loss: 0.6026 - precision: 0.7109 - recall: 0.7109
# Epoch 27/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 140ms/step - accuracy: 0.6678 - auc: 0.7025 - loss: 0.6301 - precision: 0.6607 - recall: 0.7880
# Epoch 28/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.6747 - auc: 0.7285 - loss: 0.6061 - precision: 0.6839 - recall: 0.7366
# Epoch 29/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - accuracy: 0.6667 - auc: 0.7190 - loss: 0.6115 - precision: 0.6630 - recall: 0.7752
# Epoch 30/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - accuracy: 0.6574 - auc: 0.7154 - loss: 0.6150 - precision: 0.6687 - recall: 0.7216
# Epoch 31/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 144ms/step - accuracy: 0.6805 - auc: 0.7306 - loss: 0.6030 - precision: 0.6568 - recall: 0.8522
# Epoch 32/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 147ms/step - accuracy: 0.6932 - auc: 0.7687 - loss: 0.5778 - precision: 0.7089 - recall: 0.7302
# Epoch 33/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 140ms/step - accuracy: 0.6909 - auc: 0.7509 - loss: 0.5878 - precision: 0.6955 - recall: 0.7580
# Epoch 34/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 138ms/step - accuracy: 0.7105 - auc: 0.7769 - loss: 0.5612 - precision: 0.7053 - recall: 0.7944
# Epoch 35/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 151ms/step - accuracy: 0.7013 - auc: 0.7340 - loss: 0.6395 - precision: 0.6992 - recall: 0.7816
# dict_keys(['accuracy', 'auc', 'loss', 'precision', 'recall'])

# %%
# evaluate
results_1 = model_1.evaluate(test_dataset, return_dict=True)
print(results_1)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.6959 - auc: 0.7087 - loss: 0.7987 - precision: 0.6977 - recall: 0.7692
# {'accuracy': 0.695852518081665, 'auc': 0.7087180018424988, 'loss': 0.7986871600151062, 'precision': 0.6976743936538696, 'recall': 0.7692307829856873}

# %%
# plot
plot_training_history(history)

# %%
# predict
threshold = 0.5

y_prob_1 = model_1.predict(test_dataset)
y_pred_1 = (y_prob_1 > threshold).astype(int)
y_true_1 = test_df["label"].values
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 150ms/step

# %%
plot_confusion_matrix(y_true_1, y_pred_1)
# Out:
# [[61 39]
#  [27 90]]
#               precision    recall  f1-score   support
#
#       Benign       0.69      0.61      0.65       100
#    Malignant       0.70      0.77      0.73       117
#
#     accuracy                           0.70       217
#    macro avg       0.70      0.69      0.69       217
# weighted avg       0.70      0.70      0.69       217

# %% [markdown]
# # Model 2

# %%
model_2.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)               │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 109, 109, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 54, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 52, 52, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 26, 26, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 109,889 (429.25 KB)
#  Trainable params: 109,889 (429.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
#compile
model_2.compile(
  optimizer='adam',
  loss='binary_crossentropy',
  # medical classificaitons metrics care more about AUC, Precision, and Recall
  metrics=[
    "accuracy",
    tf.keras.metrics.AUC(name="auc"),
    tf.keras.metrics.Precision(name="precision"),
    tf.keras.metrics.Recall(name="recall"),
  ]
)

# %%
# training
EPOCHS = 35

history_2 = model_2.fit(
  train_dataset,
  epochs=EPOCHS
)

print(history_2.history.keys())
# Out:
# Epoch 1/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 14s 272ms/step - accuracy: 0.5190 - auc: 0.5182 - loss: 2.4643 - precision: 0.5568 - recall: 0.5246
# Epoch 2/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - accuracy: 0.5675 - auc: 0.5755 - loss: 0.7106 - precision: 0.5927 - recall: 0.6296
# Epoch 3/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - accuracy: 0.5594 - auc: 0.5635 - loss: 0.7137 - precision: 0.5866 - recall: 0.6167
# Epoch 4/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 152ms/step - accuracy: 0.5755 - auc: 0.5899 - loss: 0.6853 - precision: 0.6029 - recall: 0.6210
# Epoch 5/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 143ms/step - accuracy: 0.5767 - auc: 0.5965 - loss: 0.7190 - precision: 0.5984 - recall: 0.6510
# Epoch 6/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.5698 - auc: 0.5955 - loss: 0.7111 - precision: 0.6022 - recall: 0.5931
# Epoch 7/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.5836 - auc: 0.6169 - loss: 0.6979 - precision: 0.6183 - recall: 0.5931
# Epoch 8/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - accuracy: 0.5975 - auc: 0.6428 - loss: 0.6990 - precision: 0.6379 - recall: 0.5846
# Epoch 9/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 140ms/step - accuracy: 0.6113 - auc: 0.6460 - loss: 0.6603 - precision: 0.6377 - recall: 0.6445
# Epoch 10/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 143ms/step - accuracy: 0.5859 - auc: 0.6129 - loss: 0.6789 - precision: 0.6200 - recall: 0.5974
# Epoch 11/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 149ms/step - accuracy: 0.5825 - auc: 0.6131 - loss: 0.6744 - precision: 0.6235 - recall: 0.5675
# Epoch 12/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 139ms/step - accuracy: 0.6021 - auc: 0.6716 - loss: 0.6470 - precision: 0.6473 - recall: 0.5739
# Epoch 13/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.6159 - auc: 0.6395 - loss: 0.6632 - precision: 0.6196 - recall: 0.7430
# Epoch 14/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 151ms/step - accuracy: 0.6205 - auc: 0.6750 - loss: 0.6512 - precision: 0.6651 - recall: 0.5953
# Epoch 15/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 140ms/step - accuracy: 0.6505 - auc: 0.7028 - loss: 0.6363 - precision: 0.6847 - recall: 0.6510
# Epoch 16/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.6597 - auc: 0.6972 - loss: 0.6281 - precision: 0.6673 - recall: 0.7345
# Epoch 17/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.6390 - auc: 0.6809 - loss: 0.6833 - precision: 0.6624 - recall: 0.6724
# Epoch 18/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.4960 - auc: 0.5000 - loss: 0.7902 - precision: 0.5299 - recall: 0.5696
# Epoch 19/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 138ms/step - accuracy: 0.5444 - auc: 0.5750 - loss: 0.6786 - precision: 0.5769 - recall: 0.5782
# Epoch 20/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - accuracy: 0.5755 - auc: 0.5864 - loss: 0.6741 - precision: 0.5840 - recall: 0.7366
# Epoch 21/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - accuracy: 0.5709 - auc: 0.6084 - loss: 0.6686 - precision: 0.5895 - recall: 0.6702
# Epoch 22/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - accuracy: 0.6251 - auc: 0.6805 - loss: 0.6536 - precision: 0.6543 - recall: 0.6445
# Epoch 23/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 140ms/step - accuracy: 0.6448 - auc: 0.6919 - loss: 0.6410 - precision: 0.6695 - recall: 0.6724
# Epoch 24/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 150ms/step - accuracy: 0.6217 - auc: 0.6639 - loss: 0.6628 - precision: 0.6376 - recall: 0.6895
# Epoch 25/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - accuracy: 0.6390 - auc: 0.6741 - loss: 0.6513 - precision: 0.6604 - recall: 0.6788
# Epoch 26/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.6851 - auc: 0.7295 - loss: 0.6145 - precision: 0.6925 - recall: 0.7473
# Epoch 27/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 144ms/step - accuracy: 0.6667 - auc: 0.7154 - loss: 0.6211 - precision: 0.6802 - recall: 0.7195
# Epoch 28/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - accuracy: 0.6759 - auc: 0.7346 - loss: 0.5944 - precision: 0.6729 - recall: 0.7752
# Epoch 29/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.6632 - auc: 0.7163 - loss: 0.6315 - precision: 0.6882 - recall: 0.6852
# Epoch 30/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - accuracy: 0.6574 - auc: 0.6781 - loss: 0.6654 - precision: 0.6568 - recall: 0.7623
# Epoch 31/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 150ms/step - accuracy: 0.6794 - auc: 0.7206 - loss: 0.6279 - precision: 0.6917 - recall: 0.7302
# Epoch 32/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.5721 - auc: 0.5822 - loss: 0.7406 - precision: 0.5949 - recall: 0.6445
# Epoch 33/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - accuracy: 0.5594 - auc: 0.6135 - loss: 0.6731 - precision: 0.6055 - recall: 0.5225
# Epoch 34/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 147ms/step - accuracy: 0.6344 - auc: 0.6824 - loss: 0.6411 - precision: 0.6659 - recall: 0.6445
# Epoch 35/35
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 144ms/step - accuracy: 0.6171 - auc: 0.6756 - loss: 0.6367 - precision: 0.6347 - recall: 0.6809
# dict_keys(['accuracy', 'auc', 'loss', 'precision', 'recall'])

# %%
# evaluate
results_2 = model_2.evaluate(test_dataset, return_dict=True)
print(results_2)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 404ms/step - accuracy: 0.6636 - auc: 0.7362 - loss: 0.6436 - precision: 0.6549 - recall: 0.7949
# {'accuracy': 0.6635944843292236, 'auc': 0.7362393736839294, 'loss': 0.6435627937316895, 'precision': 0.6549295783042908, 'recall': 0.7948718070983887}

# %%
# plot
plot_training_history(history_2)

# %%
# predict
threshold = 0.5

y_prob_2 = model_2.predict(test_dataset)
y_pred_2 = (y_prob_2 > threshold).astype(int)
y_true_2 = test_df["label"].values
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 160ms/step

# %%
plot_confusion_matrix(y_true_2, y_pred_2)
# Out:
# [[51 49]
#  [24 93]]
#               precision    recall  f1-score   support
#
#       Benign       0.68      0.51      0.58       100
#    Malignant       0.65      0.79      0.72       117
#
#     accuracy                           0.66       217
#    macro avg       0.67      0.65      0.65       217
# weighted avg       0.67      0.66      0.66       217

# %% [markdown]
# # Save Models

# %%
# Save the model to google drive
model_dir = Path("/content/drive/MyDrive/Grad_School/SEIS_766 Vision AI/final_project/models")
model_dir.mkdir(parents=True, exist_ok=True)

model_1_path = model_dir / "melanoma_cnn_arch1_35epochs.keras"
model_1.save(model_1_path)

model_2_path = model_dir / "melanoma_cnn_arch2_35epochs.keras"
model_2.save(model_2_path)

# %% [markdown]
# ## Loading the model
#
# Another user can load the saved model with:
#
# ```python
# import tensorflow as tf
#
# model = tf.keras.models.load_model(
#     "/content/drive/MyDrive/.../melanoma_cnn_arch1_35epochs.keras"
# )
# ```
#
# To use the model correctly, images should be preprocessed the same way they were during training:
#
# - resize to `224 x 224`
# - convert to `float32`
# - scale pixel values to `[0, 1]`
# - add a batch dimension before prediction
#
# Example for predicting one image:
#
# ```python
# import tensorflow as tf
# import numpy as np
#
# IMG_SIZE = (224, 224)
# THRESHOLD = 0.5
#
# def preprocess_image(image_path):
#     img = tf.keras.utils.load_img(image_path, target_size=IMG_SIZE)
#     img = tf.keras.utils.img_to_array(img)
#     img = img.astype("float32") / 255.0
#     img = np.expand_dims(img, axis=0)
#     return img
#
# model = tf.keras.models.load_model(
#     "/content/drive/MyDrive/.../melanoma_cnn_arch1_35epochs.keras"
# )
#
# image_path = "example.jpg"
# image_tensor = preprocess_image(image_path)
#
# prediction = model.predict(image_tensor, verbose=0)[0][0]
# predicted_label = "Malignant" if prediction >= THRESHOLD else "Benign"
#
# print(f"Malignant probability: {prediction:.4f}")
# print(f"Predicted label: {predicted_label}")
# ```
#
# Interpretation:
#
# - output close to `1.0` means the model predicts the image is more likely malignant
# - output close to `0.0` means the model predicts the image is more likely benign
# - this notebook used a threshold of `0.5` for classification
