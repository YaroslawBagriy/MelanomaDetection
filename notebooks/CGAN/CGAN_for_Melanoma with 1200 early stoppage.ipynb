# %%
from google.colab import drive
drive.mount('/content/drive')
#below where the file is in gdrive, change with yours
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install tensorflow
# import all necessary libraries
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import layers, Model, Input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import VGG16
import random
from sklearn.metrics import confusion_matrix
import seaborn as sns
import math
from sklearn.metrics import classification_report
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from matplotlib.image import imread
import os
import shutil
from sklearn.model_selection import train_test_split
import urllib.request
from PIL import Image
import requests
from io import BytesIO
import numpy as np
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (2.21.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow) (26.0)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (7.34.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.80.0)
# Requirement already satisfied: keras>=3.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.13.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow) (0.47.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.12.0->tensorflow) (14.3.3)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.12.0->tensorflow) (0.19.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2026.2.25)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.12.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.12.0->tensorflow) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow) (0.1.2)

# %%
df_GT = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/Data/ISIC_2020_Training_GroundTruth_v2.csv')
df_GT
# Out:
#          image_name  patient_id   lesion_id     sex  age_approx  \
# 0      ISIC_2637011  IP_7279968  IL_7972535    male        45.0
# 1      ISIC_0015719  IP_3075186  IL_4649854  female        45.0
# 2      ISIC_0052212  IP_2842074  IL_9087444  female        50.0
# 3      ISIC_0068279  IP_6890425  IL_4255399  female        45.0
# 4      ISIC_0074268  IP_8723313  IL_6898037  female        55.0
# ...             ...         ...         ...     ...         ...
# 33121  ISIC_9999134  IP_6526534  IL_2076932    male        50.0
# 33122  ISIC_9999320  IP_3650745  IL_6891604    male        65.0
# 33123  ISIC_9999515  IP_2026598  IL_6364820    male        20.0
# 33124  ISIC_9999666  IP_7702038  IL_6048457    male        50.0
# 33125  ISIC_9999806  IP_0046310  IL_5788213    male        45.0
#
#       anatom_site_general_challenge diagnosis benign_malignant  target
# 0                         head/neck   unknown           benign       0
# 1                   upper extremity   unknown           benign       0
# 2                   lower extremity     nevus           benign       0
# 3                         head/neck   unknown           benign       0
# 4                   upper extremity   unknown           benign       0
# ...                             ...       ...              ...     ...
# 33121                         torso   unknown           benign       0
# 33122                         torso   unknown           benign       0
# 33123               lower extremity   unknown           benign       0
# 33124               lower extremity   unknown           benign       0
# 33125                         torso     nevus           benign       0
#
# [33126 rows x 9 columns]

# %%
# Fix: Use a list of column names (double brackets) to select multiple columns
name = df_GT[["image_name", "benign_malignant"]]
name.head()
# Out:
#      image_name benign_malignant
# 0  ISIC_2637011           benign
# 1  ISIC_0015719           benign
# 2  ISIC_0052212           benign
# 3  ISIC_0068279           benign
# 4  ISIC_0074268           benign

# %%
name.shape
# Out:
# (33126, 2)

# %%
training_file = "/data/images_new/train"

# %%
test_file = "/data/images_new/test"

# %%
import os
import shutil

def organize_images_into_classes(source_image_dir, target_base_dir, label_df):
    organized_path = os.path.join(target_base_dir, 'organized_data')
    benign_path = os.path.join(organized_path, 'benign')
    malignant_path = os.path.join(organized_path, 'malignant')

    # 1. Immediate Cache Check
    if os.path.exists(benign_path) and os.path.exists(malignant_path):
        b_count = len(os.listdir(benign_path))
        m_count = len(os.listdir(malignant_path))
        if b_count > 0 or m_count > 0:
            print(f"Cache Found: Data already exists in {organized_path}")
            print(f"Total Benign: {b_count}")
            print(f"Total Malignant: {m_count}")
            return

    # Create class directories
    os.makedirs(benign_path, exist_ok=True)
    os.makedirs(malignant_path, exist_ok=True)

    # Create lookup map
    label_map = dict(zip(label_df['image_name'], label_df['benign_malignant']))

    # Sort images directly from the source_image_dir
    count = 0
    for root, dirs, files in os.walk(source_image_dir):
        for file in files:
            if file.lower().endswith('.jpg'):
                img_id = os.path.splitext(file)[0]
                if img_id in label_map:
                    label_class = label_map[img_id]
                    src = os.path.join(root, file)
                    dst_dir = os.path.join(organized_path, label_class)
                    os.makedirs(dst_dir, exist_ok=True) # Ensure destination directory exists
                    dst = os.path.join(dst_dir, file)

                    if not os.path.exists(dst):
                        shutil.copy(src, dst)
                        count += 1

    print(f"Organized {count} new images.")
    print(f"Total Benign: {len(os.listdir(benign_path))}")
    print(f"Total Malignant: {len(os.listdir(malignant_path))}")

# %%
train_target = "/content/drive/MyDrive/Colab_Notebooks/Data/Skin_image/Skin_train"

# %%
test_target = "/content/drive/MyDrive/Colab_Notebooks/Data/Skin_image/Skin_test"

# %%
organize_images_into_classes(training_file, train_target, name)
# Out:
# Cache Found: Data already exists in /content/drive/MyDrive/Colab_Notebooks/Data/Skin_image/Skin_train/organized_data
# Total Benign: 400
# Total Malignant: 467

# %%
organize_images_into_classes(test_file,test_target, name)
# Out:
# Cache Found: Data already exists in /content/drive/MyDrive/Colab_Notebooks/Data/Skin_image/Skin_test/organized_data
# Total Benign: 100
# Total Malignant: 117

# %%
train_data_set= "/content/drive/MyDrive/Colab_Notebooks/Data/Skin_image/Skin_train/organized_data"

# %%
test_data_set= "/content/drive/MyDrive/Colab_Notebooks/Data/Skin_image/Skin_test/organized_data"

# %%
#function to display image from our dataset
def display_sample_images(class_name, dataset_path):
    folder_path = os.path.join(dataset_path, class_name)
    images = random.sample(os.listdir(folder_path), 5)
    plt.figure(figsize=(15, 5))
    for idx, img_name in enumerate(images):
        img = imread(os.path.join(folder_path, img_name))
        plt.subplot(1, 5, idx+1)
        plt.imshow(img)
        plt.title(class_name)
        plt.axis('off')
    plt.show()

display_sample_images('malignant',train_data_set)
display_sample_images('benign',train_data_set)

# %%
img_height, img_width = 128, 128
IMG_SHAPE = (img_height, img_width, 3)
NOISE_DIM = 100
batch_size = 32
NUM_CLASSES = 2
EPOCHS = 1200
D_LR = 1e-4  # Lower learning rate for Discriminator to prevent it from overpowering the generator
G_LR = 2e-4  # Standard learning rate for Generator
BETA_1 = 0.5

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,          # Normalize pixel values
)

# %%
test_datagen = ImageDataGenerator(
    rescale=1./255,          # Normalize pixel values
)

# %%
train_generator = train_datagen.flow_from_directory(
    train_data_set,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary',
    subset='training'        # Set as training data
)
# Out:
# Found 867 images belonging to 2 classes.

# %%
test_generator = test_datagen.flow_from_directory(
    test_data_set,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary',
    subset='training'
)
# Out:
# Found 217 images belonging to 2 classes.

# %%
def build_generator(noise_dim, num_classes, img_shape):
    # Latent vector input
    noise_input = Input(shape=(noise_dim,), name='noise_input')

    # Label input
    label_input = Input(shape=(1,), name='label_input')
    # Use embedding dimension 50
    label_embedding = layers.Embedding(num_classes, 50)(label_input)
    label_embedding = layers.Flatten()(label_embedding)

    # Concatenate noise and label embeddings instead of multiplying to preserve the signal
    merged_input = layers.concatenate([noise_input, label_embedding])

    # First dense layer to upsample merged input
    x = layers.Dense(4 * 4 * 256, use_bias=False)(merged_input)
    x = layers.BatchNormalization()(x)
    x = layers.LeakyReLU()(x)

    # Reshape to appropriate dimensions before Conv2DTranspose
    x = layers.Reshape((4, 4, 256))(x)

    # Upsampling layers
    x = layers.Conv2DTranspose(256, (5, 5), strides=(2, 2), padding='same', use_bias=False)(x) # 4x4 -> 8x8
    x = layers.BatchNormalization()(x)
    x = layers.LeakyReLU()(x)

    x = layers.Conv2DTranspose(128, (5, 5), strides=(2, 2), padding='same', use_bias=False)(x) # 8x8 -> 16x16
    x = layers.BatchNormalization()(x)
    x = layers.LeakyReLU()(x)

    x = layers.Conv2DTranspose(64, (5, 5), strides=(2, 2), padding='same', use_bias=False)(x) # 16x16 -> 32x32
    x = layers.BatchNormalization()(x)
    x = layers.LeakyReLU()(x)

    x = layers.Conv2DTranspose(32, (5, 5), strides=(2, 2), padding='same', use_bias=False)(x) # 32x32 -> 64x64
    x = layers.BatchNormalization()(x)
    x = layers.LeakyReLU()(x)

    # Final Conv2DTranspose to reach exactly 128x128
    # IMPORTANT: use_bias=True allows the generator to shift the baseline color away from 0 (gray)
    x = layers.Conv2DTranspose(3, (5, 5), strides=(2, 2), padding='same', use_bias=True, activation='tanh')(x) # 64x64 -> 128x128

    generator = Model([noise_input, label_input], x, name='generator')
    return generator

# Build the generator
generator = build_generator(NOISE_DIM, NUM_CLASSES, IMG_SHAPE)
generator.summary()
# Out:
# Model: "generator"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ label_input         │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_2         │ (None, 1, 50)     │        100 │ label_input[0][0] │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ noise_input         │ (None, 100)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_2 (Flatten) │ (None, 50)        │          0 │ embedding_2[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 150)       │          0 │ noise_input[0][0… │
# │ (Concatenate)       │                   │            │ flatten_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 4096)      │    614,400 │ concatenate_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4096)      │     16,384 │ dense_2[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_9       │ (None, 4096)      │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_2 (Reshape) │ (None, 4, 4, 256) │          0 │ leaky_re_lu_9[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_5  │ (None, 8, 8, 256) │  1,638,400 │ reshape_2[0][0]   │
# │ (Conv2DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 256) │      1,024 │ conv2d_transpose… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_10      │ (None, 8, 8, 256) │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_6  │ (None, 16, 16,    │    819,200 │ leaky_re_lu_10[0… │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_11      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_7  │ (None, 32, 32,    │    204,800 │ leaky_re_lu_11[0… │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_12      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_8  │ (None, 64, 64,    │     51,200 │ leaky_re_lu_12[0… │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_13      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_9  │ (None, 128, 128,  │      2,403 │ leaky_re_lu_13[0… │
# │ (Conv2DTranspose)   │ 3)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 3,348,807 (12.77 MB)
#  Trainable params: 3,339,655 (12.74 MB)
#  Non-trainable params: 9,152 (35.75 KB)

# %% [markdown]
# Next, we will define the Discriminator model. This model will take an image and a class label and predict whether the image is real or fake.

# %%
def build_discriminator(num_classes, img_shape):
    # Image input
    image_input = Input(shape=img_shape, name='image_input')

    # Label input
    label_input = Input(shape=(1,), name='label_input')
    label_embedding = layers.Embedding(num_classes, img_shape[0] * img_shape[1])(label_input) # Embed label to image size
    label_embedding = layers.Reshape((img_shape[0], img_shape[1], 1))(label_embedding) # Reshape to concatenate with image

    # Concatenate image and label embedding
    merged_input = layers.concatenate([image_input, label_embedding], axis=-1) # Concatenate along the channel axis

    # Downsampling layers - Made deeper to match the generator's complexity
    x = layers.Conv2D(64, (4, 4), strides=(2, 2), padding='same')(merged_input)
    x = layers.LeakyReLU(alpha=0.2)(x)
    x = layers.Dropout(0.3)(x)

    x = layers.Conv2D(128, (4, 4), strides=(2, 2), padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.LeakyReLU(alpha=0.2)(x)
    x = layers.Dropout(0.3)(x)

    x = layers.Conv2D(256, (4, 4), strides=(2, 2), padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.LeakyReLU(alpha=0.2)(x)
    x = layers.Dropout(0.3)(x)

    x = layers.Conv2D(512, (4, 4), strides=(2, 2), padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.LeakyReLU(alpha=0.2)(x)
    x = layers.Dropout(0.3)(x)

    # Flatten and output
    x = layers.Flatten()(x)
    output = layers.Dense(1, activation='sigmoid')(x) # Binary classification (real/fake)

    discriminator = Model([image_input, label_input], output, name='discriminator')
    return discriminator

# Build the discriminator
discriminator = build_discriminator(NUM_CLASSES, IMG_SHAPE)
discriminator.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Model: "discriminator"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ label_input         │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_3         │ (None, 1, 16384)  │     32,768 │ label_input[0][0] │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ image_input         │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_3 (Reshape) │ (None, 128, 128,  │          0 │ embedding_3[0][0] │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 128, 128,  │          0 │ image_input[0][0… │
# │ (Concatenate)       │ 4)                │            │ reshape_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 64, 64,    │      4,160 │ concatenate_3[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_14      │ (None, 64, 64,    │          0 │ conv2d_4[0][0]    │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 64, 64,    │          0 │ leaky_re_lu_14[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 32, 32,    │    131,200 │ dropout_4[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_15      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 32, 32,    │          0 │ leaky_re_lu_15[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 16, 16,    │    524,544 │ dropout_5[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_16      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 16, 16,    │          0 │ leaky_re_lu_16[0… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 8, 8, 512) │  2,097,664 │ dropout_6[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 512) │      2,048 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_17      │ (None, 8, 8, 512) │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 8, 8, 512) │          0 │ leaky_re_lu_17[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_3 (Flatten) │ (None, 32768)     │          0 │ dropout_7[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 1)         │     32,769 │ flatten_3[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,826,689 (10.78 MB)
#  Trainable params: 2,824,897 (10.78 MB)
#  Non-trainable params: 1,792 (7.00 KB)

# %% [markdown]
# Now we will compile both the discriminator and the combined CGAN model. The discriminator is trained to distinguish between real and fake images, while the generator is trained through the combined model to fool the discriminator.

# %%
# Compile the discriminator with the lower D_LR
discriminator.compile(optimizer=Adam(learning_rate=D_LR, beta_1=BETA_1),
                      loss='binary_crossentropy',
                      metrics=['accuracy'])

# Build the combined GAN model
discriminator.trainable = False # Discriminator weights are frozen during generator training

noise_input = Input(shape=(NOISE_DIM,), name='noise_input_gan')
label_input = Input(shape=(1,), name='label_input_gan')

fake_image = generator([noise_input, label_input])

discriminator_output = discriminator([fake_image, label_input])

# Compile the CGAN model with the standard G_LR
cgan_model = Model([noise_input, label_input], discriminator_output, name='cgan_model')
cgan_model.compile(optimizer=Adam(learning_rate=G_LR, beta_1=BETA_1),
                   loss='binary_crossentropy')

cgan_model.summary()
# Out:
# Model: "cgan_model"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ noise_input_gan     │ (None, 100)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ label_input_gan     │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ generator           │ (None, 128, 128,  │  3,348,807 │ noise_input_gan[… │
# │ (Functional)        │ 3)                │            │ label_input_gan[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ discriminator       │ (None, 1)         │  2,826,689 │ generator[0][0],  │
# │ (Functional)        │                   │            │ label_input_gan[… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 6,175,496 (23.56 MB)
#  Trainable params: 3,339,655 (12.74 MB)
#  Non-trainable params: 2,835,841 (10.82 MB)

# %%
def train_cgan(generator, discriminator, cgan_model, train_generator, noise_dim, epochs, batch_size, num_classes, patience_epochs=50, min_delta_loss=0.001):
    best_g_loss = float('inf')
    patience_counter = 0

    # Lists to store history for plotting
    history = {
        'd_loss_real': [], 'd_loss_fake': [],
        'd_acc_real': [], 'd_acc_fake': [],
        'g_loss': []
    }

    for epoch in range(epochs):
        print(f"\nEpoch {epoch + 1}/{epochs}")

        # Re-initialize iterator at the start of each epoch
        train_iterator = iter(train_generator)

        d_loss_list_real = []
        d_loss_list_fake = []
        d_acc_list_real = []
        d_acc_list_fake = []
        g_loss_list = []

        for i in range(train_generator.samples // batch_size):
            # Get real images and labels
            real_images, real_labels_binary = next(train_iterator)

            # Convert binary labels to integer labels (0 or 1) for embedding layer
            real_labels_int = real_labels_binary.astype(int)
            real_labels_int = real_labels_int.reshape(-1, 1)

            # Rescale real images from [0, 1] to [-1, 1] to match generator output
            real_images_scaled = (real_images * 2) - 1

            # Get the actual batch size for the current real images
            current_batch_size = real_images.shape[0]

            # Generate fake images
            noise = np.random.normal(0, 1, (current_batch_size, noise_dim))
            fake_labels_int = np.random.randint(0, num_classes, current_batch_size)
            fake_labels_int_reshaped = fake_labels_int.reshape(-1, 1)

            fake_images = generator.predict([noise, fake_labels_int_reshaped], verbose=0)

            # --- LABEL SMOOTHING ---
            real_target_labels = np.ones((current_batch_size, 1)) * 0.9
            fake_target_labels = np.ones((current_batch_size, 1)) * 0.1

            # === Discriminator Training Phase ===
            discriminator.trainable = True # Unfreeze for discriminator training

            # Train discriminator on real images
            d_loss_real, d_acc_real = discriminator.train_on_batch([real_images_scaled, real_labels_int], real_target_labels)
            d_loss_list_real.append(d_loss_real)
            d_acc_list_real.append(d_acc_real)

            # Train discriminator on fake images
            d_loss_fake, d_acc_fake = discriminator.train_on_batch([fake_images, fake_labels_int_reshaped], fake_target_labels)
            d_loss_list_fake.append(d_loss_fake)
            d_acc_list_fake.append(d_acc_fake)

            # === Generator Training Phase ===
            discriminator.trainable = False # Freeze discriminator when training the generator

            # Train generator ONCE (removed loop) to keep balance
            noise = np.random.normal(0, 1, (batch_size, noise_dim))
            gen_labels = np.random.randint(0, num_classes, batch_size)
            gen_labels_reshaped = gen_labels.reshape(-1, 1)

            g_target_labels = np.ones((batch_size, 1))

            g_loss = cgan_model.train_on_batch([noise, gen_labels_reshaped], g_target_labels)
            g_loss_list.append(g_loss)

        # Calculate average losses
        avg_d_loss_real = np.mean(d_loss_list_real)
        avg_d_loss_fake = np.mean(d_loss_list_fake)
        avg_d_acc_real = np.mean(d_acc_list_real)
        avg_d_acc_fake = np.mean(d_acc_list_fake)
        avg_g_loss = np.mean(g_loss_list)

        print(f"  Discriminator (Real): Loss = {avg_d_loss_real:.4f}, Acc = {avg_d_acc_real:.4f}")
        print(f"  Discriminator (Fake): Loss = {avg_d_loss_fake:.4f}, Acc = {avg_d_acc_fake:.4f}")
        print(f"  Generator: Loss = {avg_g_loss:.4f}")

        # Append to history
        history['d_loss_real'].append(avg_d_loss_real)
        history['d_loss_fake'].append(avg_d_loss_fake)
        history['d_acc_real'].append(avg_d_acc_real)
        history['d_acc_fake'].append(avg_d_acc_fake)
        history['g_loss'].append(avg_g_loss)

        # Early Stopping Logic (adjusted patience for GAN stability)
        if avg_g_loss < best_g_loss - min_delta_loss:
            best_g_loss = avg_g_loss
            patience_counter = 0
        else:
            patience_counter += 1
            if patience_counter >= patience_epochs:
                print(f"Early stopping triggered after {epoch + 1} epochs.")
                break

    return history

# Force model building by making a dummy prediction before starting training
import tensorflow as tf
dummy_noise = tf.convert_to_tensor(np.random.normal(0, 1, (batch_size, NOISE_DIM)), dtype=tf.float32)
dummy_labels = tf.convert_to_tensor(np.random.randint(0, NUM_CLASSES, batch_size).reshape(-1, 1), dtype=tf.int32)
_ = generator.predict([dummy_noise, dummy_labels], verbose=0)

# Start training and capture history
history = train_cgan(generator, discriminator, cgan_model, train_generator, NOISE_DIM, EPOCHS, batch_size, NUM_CLASSES)
# Out:
# Epoch 1/1200
#   Discriminator (Real): Loss = 0.5507, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.5594, Acc = 0.0000
#   Generator: Loss = 0.4932
#
# Epoch 2/1200
#   Discriminator (Real): Loss = 0.4478, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.4482, Acc = 0.0000
#   Generator: Loss = 0.2689
#
# Epoch 3/1200
#   Discriminator (Real): Loss = 0.4406, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.4409, Acc = 0.0000
#   Generator: Loss = 0.1766
#
# Epoch 4/1200
#   Discriminator (Real): Loss = 0.4326, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.4324, Acc = 0.0000
#   Generator: Loss = 0.1304
#
# Epoch 5/1200
#   Discriminator (Real): Loss = 0.4369, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.4377, Acc = 0.0000
#   Generator: Loss = 0.1122
#
# Epoch 6/1200
#   Discriminator (Real): Loss = 0.4561, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.4563, Acc = 0.0000
#   Generator: Loss = 0.1163
#
# Epoch 7/1200
#   Discriminator (Real): Loss = 0.4524, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.4524, Acc = 0.0000
#   Generator: Loss = 0.1009
#
# Epoch 8/1200
#   Discriminator (Real): Loss = 0.4457, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.4456, Acc = 0.0000
#   Generator: Loss = 0.0879
#
# Epoch 9/1200
#   Discriminator (Real): Loss = 0.4401, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.4401, Acc = 0.0000
#   Generator: Loss = 0.0779
#
# Epoch 10/1200
#   Discriminator (Real): Loss = 0.4354, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.4353, Acc = 0.0000
#   Generator: Loss = 0.0698
#
# Epoch 11/1200
#   Discriminator (Real): Loss = 0.4316, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.4316, Acc = 0.0000
#   Generator: Loss = 0.0634
#
# Epoch 12/1200
#   Discriminator (Real): Loss = 0.4283, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.4282, Acc = 0.0000
#   Generator: Loss = 0.0580
#
# Epoch 13/1200
#   Discriminator (Real): Loss = 0.4240, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.4240, Acc = 0.0000
#   Generator: Loss = 0.0534
#
# Epoch 14/1200
#   Discriminator (Real): Loss = 0.4204, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.4205, Acc = 0.0000
#   Generator: Loss = 0.0496
#
# Epoch 15/1200
#   Discriminator (Real): Loss = 0.4225, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.4226, Acc = 0.0000
#   Generator: Loss = 0.0465
#
# Epoch 16/1200
#   Discriminator (Real): Loss = 0.4220, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.4220, Acc = 0.0000
#   Generator: Loss = 0.0435
#
# Epoch 17/1200
#   Discriminator (Real): Loss = 0.4196, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.4196, Acc = 0.0000
#   Generator: Loss = 0.0410
#
# Epoch 18/1200
#   Discriminator (Real): Loss = 0.4171, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.4171, Acc = 0.0000
#   Generator: Loss = 0.0387
#
# Epoch 19/1200
#   Discriminator (Real): Loss = 0.4143, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.4142, Acc = 0.0000
#   Generator: Loss = 0.0366
#
# Epoch 20/1200
#   Discriminator (Real): Loss = 0.4117, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.4117, Acc = 0.0000
#   Generator: Loss = 0.0348
#
# Epoch 21/1200
#   Discriminator (Real): Loss = 0.4097, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.4097, Acc = 0.0000
#   Generator: Loss = 0.0332
#
# Epoch 22/1200
#   Discriminator (Real): Loss = 0.4083, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.4083, Acc = 0.0000
#   Generator: Loss = 0.0317
#
# Epoch 23/1200
#   Discriminator (Real): Loss = 0.4069, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.4070, Acc = 0.0000
#   Generator: Loss = 0.0304
#
# Epoch 24/1200
#   Discriminator (Real): Loss = 0.4067, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.4067, Acc = 0.0000
#   Generator: Loss = 0.0292
#
# Epoch 25/1200
#   Discriminator (Real): Loss = 0.4051, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.4051, Acc = 0.0000
#   Generator: Loss = 0.0281
#
# Epoch 26/1200
#   Discriminator (Real): Loss = 0.4043, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.4043, Acc = 0.0000
#   Generator: Loss = 0.0270
#
# Epoch 27/1200
#   Discriminator (Real): Loss = 0.4030, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.4030, Acc = 0.0000
#   Generator: Loss = 0.0261
#
# Epoch 28/1200
#   Discriminator (Real): Loss = 0.4020, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.4020, Acc = 0.0000
#   Generator: Loss = 0.0252
#
# Epoch 29/1200
#   Discriminator (Real): Loss = 0.4012, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.4012, Acc = 0.0000
#   Generator: Loss = 0.0244
#
# Epoch 30/1200
#   Discriminator (Real): Loss = 0.4008, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.4008, Acc = 0.0000
#   Generator: Loss = 0.0236
#
# Epoch 31/1200
#   Discriminator (Real): Loss = 0.4001, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.4001, Acc = 0.0000
#   Generator: Loss = 0.0229
#
# Epoch 32/1200
#   Discriminator (Real): Loss = 0.3989, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3989, Acc = 0.0000
#   Generator: Loss = 0.0222
#
# Epoch 33/1200
#   Discriminator (Real): Loss = 0.3992, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3993, Acc = 0.0000
#   Generator: Loss = 0.0216
#
# Epoch 34/1200
#   Discriminator (Real): Loss = 0.3987, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3987, Acc = 0.0000
#   Generator: Loss = 0.0210
#
# Epoch 35/1200
#   Discriminator (Real): Loss = 0.3976, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3975, Acc = 0.0000
#   Generator: Loss = 0.0205
#
# Epoch 36/1200
#   Discriminator (Real): Loss = 0.3970, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3970, Acc = 0.0000
#   Generator: Loss = 0.0200
#
# Epoch 37/1200
#   Discriminator (Real): Loss = 0.3962, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3962, Acc = 0.0000
#   Generator: Loss = 0.0194
#
# Epoch 38/1200
#   Discriminator (Real): Loss = 0.3950, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3950, Acc = 0.0000
#   Generator: Loss = 0.0190
#
# Epoch 39/1200
#   Discriminator (Real): Loss = 0.3941, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3941, Acc = 0.0000
#   Generator: Loss = 0.0185
#
# Epoch 40/1200
#   Discriminator (Real): Loss = 0.3934, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3934, Acc = 0.0000
#   Generator: Loss = 0.0181
#
# Epoch 41/1200
#   Discriminator (Real): Loss = 0.3930, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3929, Acc = 0.0000
#   Generator: Loss = 0.0177
#
# Epoch 42/1200
#   Discriminator (Real): Loss = 0.3920, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3920, Acc = 0.0000
#   Generator: Loss = 0.0173
#
# Epoch 43/1200
#   Discriminator (Real): Loss = 0.3911, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3911, Acc = 0.0000
#   Generator: Loss = 0.0169
#
# Epoch 44/1200
#   Discriminator (Real): Loss = 0.3902, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3902, Acc = 0.0000
#   Generator: Loss = 0.0166
#
# Epoch 45/1200
#   Discriminator (Real): Loss = 0.3894, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3894, Acc = 0.0000
#   Generator: Loss = 0.0162
#
# Epoch 46/1200
#   Discriminator (Real): Loss = 0.3887, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3887, Acc = 0.0000
#   Generator: Loss = 0.0159
#
# Epoch 47/1200
#   Discriminator (Real): Loss = 0.3885, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3885, Acc = 0.0000
#   Generator: Loss = 0.0156
#
# Epoch 48/1200
#   Discriminator (Real): Loss = 0.3877, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3877, Acc = 0.0000
#   Generator: Loss = 0.0153
#
# Epoch 49/1200
#   Discriminator (Real): Loss = 0.3869, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3869, Acc = 0.0000
#   Generator: Loss = 0.0150
#
# Epoch 50/1200
#   Discriminator (Real): Loss = 0.3870, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3871, Acc = 0.0000
#   Generator: Loss = 0.0148
#
# Epoch 51/1200
#   Discriminator (Real): Loss = 0.3871, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3872, Acc = 0.0000
#   Generator: Loss = 0.0146
#
# Epoch 52/1200
#   Discriminator (Real): Loss = 0.3865, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3865, Acc = 0.0000
#   Generator: Loss = 0.0143
#
# Epoch 53/1200
#   Discriminator (Real): Loss = 0.3858, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3858, Acc = 0.0000
#   Generator: Loss = 0.0141
#
# Epoch 54/1200
#   Discriminator (Real): Loss = 0.3852, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3852, Acc = 0.0000
#   Generator: Loss = 0.0139
#
# Epoch 55/1200
#   Discriminator (Real): Loss = 0.3851, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3851, Acc = 0.0000
#   Generator: Loss = 0.0137
#
# Epoch 56/1200
#   Discriminator (Real): Loss = 0.3845, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3845, Acc = 0.0000
#   Generator: Loss = 0.0135
#
# Epoch 57/1200
#   Discriminator (Real): Loss = 0.3838, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3838, Acc = 0.0000
#   Generator: Loss = 0.0133
#
# Epoch 58/1200
#   Discriminator (Real): Loss = 0.3832, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3832, Acc = 0.0000
#   Generator: Loss = 0.0131
#
# Epoch 59/1200
#   Discriminator (Real): Loss = 0.3829, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3829, Acc = 0.0000
#   Generator: Loss = 0.0129
#
# Epoch 60/1200
#   Discriminator (Real): Loss = 0.3827, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3827, Acc = 0.0000
#   Generator: Loss = 0.0127
#
# Epoch 61/1200
#   Discriminator (Real): Loss = 0.3823, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3823, Acc = 0.0000
#   Generator: Loss = 0.0126
#
# Epoch 62/1200
#   Discriminator (Real): Loss = 0.3817, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3817, Acc = 0.0000
#   Generator: Loss = 0.0124
#
# Epoch 63/1200
#   Discriminator (Real): Loss = 0.3811, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3811, Acc = 0.0000
#   Generator: Loss = 0.0122
#
# Epoch 64/1200
#   Discriminator (Real): Loss = 0.3806, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3806, Acc = 0.0000
#   Generator: Loss = 0.0121
#
# Epoch 65/1200
#   Discriminator (Real): Loss = 0.3801, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3801, Acc = 0.0000
#   Generator: Loss = 0.0119
#
# Epoch 66/1200
#   Discriminator (Real): Loss = 0.3795, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3795, Acc = 0.0000
#   Generator: Loss = 0.0118
#
# Epoch 67/1200
#   Discriminator (Real): Loss = 0.3790, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3790, Acc = 0.0000
#   Generator: Loss = 0.0116
#
# Epoch 68/1200
#   Discriminator (Real): Loss = 0.3785, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3785, Acc = 0.0000
#   Generator: Loss = 0.0115
#
# Epoch 69/1200
#   Discriminator (Real): Loss = 0.3781, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3781, Acc = 0.0000
#   Generator: Loss = 0.0113
#
# Epoch 70/1200
#   Discriminator (Real): Loss = 0.3776, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3776, Acc = 0.0000
#   Generator: Loss = 0.0112
#
# Epoch 71/1200
#   Discriminator (Real): Loss = 0.3772, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3772, Acc = 0.0000
#   Generator: Loss = 0.0111
#
# Epoch 72/1200
#   Discriminator (Real): Loss = 0.3768, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3768, Acc = 0.0000
#   Generator: Loss = 0.0110
#
# Epoch 73/1200
#   Discriminator (Real): Loss = 0.3763, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3763, Acc = 0.0000
#   Generator: Loss = 0.0109
#
# Epoch 74/1200
#   Discriminator (Real): Loss = 0.3762, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3762, Acc = 0.0000
#   Generator: Loss = 0.0108
#
# Epoch 75/1200
#   Discriminator (Real): Loss = 0.3758, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3758, Acc = 0.0000
#   Generator: Loss = 0.0106
#
# Epoch 76/1200
#   Discriminator (Real): Loss = 0.3756, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3755, Acc = 0.0000
#   Generator: Loss = 0.0105
#
# Epoch 77/1200
#   Discriminator (Real): Loss = 0.3751, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3751, Acc = 0.0000
#   Generator: Loss = 0.0104
#
# Epoch 78/1200
#   Discriminator (Real): Loss = 0.3747, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3747, Acc = 0.0000
#   Generator: Loss = 0.0103
#
# Epoch 79/1200
#   Discriminator (Real): Loss = 0.3743, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3743, Acc = 0.0000
#   Generator: Loss = 0.0102
#
# Epoch 80/1200
#   Discriminator (Real): Loss = 0.3742, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3742, Acc = 0.0000
#   Generator: Loss = 0.0102
#
# Epoch 81/1200
#   Discriminator (Real): Loss = 0.3738, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3738, Acc = 0.0000
#   Generator: Loss = 0.0101
#
# Epoch 82/1200
#   Discriminator (Real): Loss = 0.3734, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3734, Acc = 0.0000
#   Generator: Loss = 0.0100
#
# Epoch 83/1200
#   Discriminator (Real): Loss = 0.3730, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3730, Acc = 0.0000
#   Generator: Loss = 0.0099
#
# Epoch 84/1200
#   Discriminator (Real): Loss = 0.3729, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3729, Acc = 0.0000
#   Generator: Loss = 0.0099
#
# Epoch 85/1200
#   Discriminator (Real): Loss = 0.3727, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3727, Acc = 0.0000
#   Generator: Loss = 0.0098
#
# Epoch 86/1200
#   Discriminator (Real): Loss = 0.3723, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3723, Acc = 0.0000
#   Generator: Loss = 0.0097
#
# Epoch 87/1200
#   Discriminator (Real): Loss = 0.3719, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3719, Acc = 0.0000
#   Generator: Loss = 0.0096
#
# Epoch 88/1200
#   Discriminator (Real): Loss = 0.3716, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3716, Acc = 0.0000
#   Generator: Loss = 0.0096
#
# Epoch 89/1200
#   Discriminator (Real): Loss = 0.3712, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3712, Acc = 0.0000
#   Generator: Loss = 0.0095
#
# Epoch 90/1200
#   Discriminator (Real): Loss = 0.3709, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3709, Acc = 0.0000
#   Generator: Loss = 0.0094
#
# Epoch 91/1200
#   Discriminator (Real): Loss = 0.3706, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3706, Acc = 0.0000
#   Generator: Loss = 0.0094
#
# Epoch 92/1200
#   Discriminator (Real): Loss = 0.3704, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3704, Acc = 0.0000
#   Generator: Loss = 0.0093
#
# Epoch 93/1200
#   Discriminator (Real): Loss = 0.3701, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3701, Acc = 0.0000
#   Generator: Loss = 0.0093
#
# Epoch 94/1200
#   Discriminator (Real): Loss = 0.3698, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3698, Acc = 0.0000
#   Generator: Loss = 0.0092
#
# Epoch 95/1200
#   Discriminator (Real): Loss = 0.3695, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3695, Acc = 0.0000
#   Generator: Loss = 0.0092
#
# Epoch 96/1200
#   Discriminator (Real): Loss = 0.3692, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3692, Acc = 0.0000
#   Generator: Loss = 0.0091
#
# Epoch 97/1200
#   Discriminator (Real): Loss = 0.3689, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3689, Acc = 0.0000
#   Generator: Loss = 0.0091
#
# Epoch 98/1200
#   Discriminator (Real): Loss = 0.3686, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3686, Acc = 0.0000
#   Generator: Loss = 0.0090
#
# Epoch 99/1200
#   Discriminator (Real): Loss = 0.3685, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3685, Acc = 0.0000
#   Generator: Loss = 0.0090
#
# Epoch 100/1200
#   Discriminator (Real): Loss = 0.3682, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3682, Acc = 0.0000
#   Generator: Loss = 0.0090
#
# Epoch 101/1200
#   Discriminator (Real): Loss = 0.3679, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3679, Acc = 0.0000
#   Generator: Loss = 0.0089
#
# Epoch 102/1200
#   Discriminator (Real): Loss = 0.3677, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3677, Acc = 0.0000
#   Generator: Loss = 0.0089
#
# Epoch 103/1200
#   Discriminator (Real): Loss = 0.3674, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3674, Acc = 0.0000
#   Generator: Loss = 0.0089
#
# Epoch 104/1200
#   Discriminator (Real): Loss = 0.3671, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3671, Acc = 0.0000
#   Generator: Loss = 0.0088
#
# Epoch 105/1200
#   Discriminator (Real): Loss = 0.3669, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3669, Acc = 0.0000
#   Generator: Loss = 0.0088
#
# Epoch 106/1200
#   Discriminator (Real): Loss = 0.3666, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3666, Acc = 0.0000
#   Generator: Loss = 0.0088
#
# Epoch 107/1200
#   Discriminator (Real): Loss = 0.3664, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3664, Acc = 0.0000
#   Generator: Loss = 0.0087
#
# Epoch 108/1200
#   Discriminator (Real): Loss = 0.3662, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3661, Acc = 0.0000
#   Generator: Loss = 0.0087
#
# Epoch 109/1200
#   Discriminator (Real): Loss = 0.3659, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3659, Acc = 0.0000
#   Generator: Loss = 0.0087
#
# Epoch 110/1200
#   Discriminator (Real): Loss = 0.3678, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3679, Acc = 0.0000
#   Generator: Loss = 0.0203
#
# Epoch 111/1200
#   Discriminator (Real): Loss = 0.3693, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3693, Acc = 0.0000
#   Generator: Loss = 0.0252
#
# Epoch 112/1200
#   Discriminator (Real): Loss = 0.3691, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3691, Acc = 0.0000
#   Generator: Loss = 0.0251
#
# Epoch 113/1200
#   Discriminator (Real): Loss = 0.3688, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3688, Acc = 0.0000
#   Generator: Loss = 0.0252
#
# Epoch 114/1200
#   Discriminator (Real): Loss = 0.3686, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3686, Acc = 0.0000
#   Generator: Loss = 0.0254
#
# Epoch 115/1200
#   Discriminator (Real): Loss = 0.3684, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3684, Acc = 0.0000
#   Generator: Loss = 0.0256
#
# Epoch 116/1200
#   Discriminator (Real): Loss = 0.3682, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3682, Acc = 0.0000
#   Generator: Loss = 0.0259
#
# Epoch 117/1200
#   Discriminator (Real): Loss = 0.3681, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3681, Acc = 0.0000
#   Generator: Loss = 0.0261
#
# Epoch 118/1200
#   Discriminator (Real): Loss = 0.3678, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3678, Acc = 0.0000
#   Generator: Loss = 0.0264
#
# Epoch 119/1200
#   Discriminator (Real): Loss = 0.3675, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3675, Acc = 0.0000
#   Generator: Loss = 0.0265
#
# Epoch 120/1200
#   Discriminator (Real): Loss = 0.3673, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3673, Acc = 0.0000
#   Generator: Loss = 0.0267
#
# Epoch 121/1200
#   Discriminator (Real): Loss = 0.3670, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3670, Acc = 0.0000
#   Generator: Loss = 0.0267
#
# Epoch 122/1200
#   Discriminator (Real): Loss = 0.3667, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3667, Acc = 0.0000
#   Generator: Loss = 0.0268
#
# Epoch 123/1200
#   Discriminator (Real): Loss = 0.3667, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3667, Acc = 0.0000
#   Generator: Loss = 0.0270
#
# Epoch 124/1200
#   Discriminator (Real): Loss = 0.3669, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3669, Acc = 0.0000
#   Generator: Loss = 0.0274
#
# Epoch 125/1200
#   Discriminator (Real): Loss = 0.3667, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3667, Acc = 0.0000
#   Generator: Loss = 0.0277
#
# Epoch 126/1200
#   Discriminator (Real): Loss = 0.3664, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3664, Acc = 0.0000
#   Generator: Loss = 0.0279
#
# Epoch 127/1200
#   Discriminator (Real): Loss = 0.3662, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3662, Acc = 0.0000
#   Generator: Loss = 0.0280
#
# Epoch 128/1200
#   Discriminator (Real): Loss = 0.3659, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3659, Acc = 0.0000
#   Generator: Loss = 0.0281
#
# Epoch 129/1200
#   Discriminator (Real): Loss = 0.3657, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3657, Acc = 0.0000
#   Generator: Loss = 0.0282
#
# Epoch 130/1200
#   Discriminator (Real): Loss = 0.3659, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3660, Acc = 0.0000
#   Generator: Loss = 0.0294
#
# Epoch 131/1200
#   Discriminator (Real): Loss = 0.3672, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3672, Acc = 0.0000
#   Generator: Loss = 0.0321
#
# Epoch 132/1200
#   Discriminator (Real): Loss = 0.3670, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3670, Acc = 0.0000
#   Generator: Loss = 0.0323
#
# Epoch 133/1200
#   Discriminator (Real): Loss = 0.3668, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3668, Acc = 0.0000
#   Generator: Loss = 0.0325
#
# Epoch 134/1200
#   Discriminator (Real): Loss = 0.3666, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3666, Acc = 0.0000
#   Generator: Loss = 0.0326
#
# Epoch 135/1200
#   Discriminator (Real): Loss = 0.3664, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3664, Acc = 0.0000
#   Generator: Loss = 0.0327
#
# Epoch 136/1200
#   Discriminator (Real): Loss = 0.3662, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3662, Acc = 0.0000
#   Generator: Loss = 0.0327
#
# Epoch 137/1200
#   Discriminator (Real): Loss = 0.3660, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3660, Acc = 0.0000
#   Generator: Loss = 0.0327
#
# Epoch 138/1200
#   Discriminator (Real): Loss = 0.3658, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3658, Acc = 0.0000
#   Generator: Loss = 0.0326
#
# Epoch 139/1200
#   Discriminator (Real): Loss = 0.3656, Acc = 0.0000
#   Discriminator (Fake): Loss = 0.3656, Acc = 0.0000
#   Generator: Loss = 0.0326
# Early stopping triggered after 139 epochs.

# %%
# Function to generate and display images for a given class
def generate_and_display_images(generator, noise_dim, num_classes, class_label, num_samples=5):
    noise = np.random.normal(0, 1, (num_samples, noise_dim))
    # Create labels for the specific class
    # Assuming 0 for benign and 1 for malignant, you might need to adjust based on your train_generator.class_indices
    if class_label == 'benign':
        labels = np.zeros(num_samples).reshape(-1, 1).astype(int)
    elif class_label == 'malignant':
        labels = np.ones(num_samples).reshape(-1, 1).astype(int)
    else:
        raise ValueError("Invalid class_label. Must be 'benign' or 'malignant'.")

    generated_images = generator.predict([noise, labels])

    # Rescale images from [-1, 1] to [0, 1] for proper visualization
    generated_images = (generated_images + 1) / 2.0

    # Debugging: Print min/max pixel values after rescaling
    print(f"Min/Max pixel value for {class_label} (rescaled): {generated_images.min():.4f}/{generated_images.max():.4f}")

    plt.figure(figsize=(15, 3))
    for i in range(num_samples):
        plt.subplot(1, num_samples, i + 1)
        # Explicitly set vmin and vmax for correct display of float images (0-1 range)
        plt.imshow(generated_images[i], vmin=0, vmax=1)
        plt.title(class_label)
        plt.axis('off')
    plt.suptitle(f'Generated {class_label} Images', fontsize=16)
    plt.show()

# %% [markdown]
# ### Retraining the CGAN with `tanh` activation in the Generator

# %% [markdown]
# ### Generated Images After Retraining

# %%
# Generate and display images for 'benign' class
generate_and_display_images(generator, NOISE_DIM, NUM_CLASSES, 'benign', num_samples=5)

# Generate and display images for 'malignant' class
generate_and_display_images(generator, NOISE_DIM, NUM_CLASSES, 'malignant', num_samples=5)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Min/Max pixel value for benign (rescaled): 0.0000/0.9994
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Min/Max pixel value for malignant (rescaled): 0.0000/0.9993

# %% [markdown]
# ### Training History After Retraining

# %%
# Plotting training history
plt.figure(figsize=(12, 6))

# Plot Discriminator Loss
plt.subplot(1, 2, 1)
plt.plot(history['d_loss_real'], label='Discriminator Loss (Real)')
plt.plot(history['d_loss_fake'], label='Discriminator Loss (Fake)')
plt.plot(history['g_loss'], label='Generator Loss')
plt.title('Losses Over Epochs (New Training)')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

# Plot Discriminator Accuracy
plt.subplot(1, 2, 2)
plt.plot(history['d_acc_real'], label='Discriminator Accuracy (Real)')
plt.plot(history['d_acc_fake'], label='Discriminator Accuracy (Fake)')
plt.title('Discriminator Accuracy Over Epochs (New Training)')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# Plotting training history
plt.figure(figsize=(12, 6))

# Plot Discriminator Loss
plt.subplot(1, 2, 1)
plt.plot(history['d_loss_real'], label='Discriminator Loss (Real)')
plt.plot(history['d_loss_fake'], label='Discriminator Loss (Fake)')
plt.plot(history['g_loss'], label='Generator Loss')
plt.title('Losses Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

# Plot Discriminator Accuracy
plt.subplot(1, 2, 2)
plt.plot(history['d_acc_real'], label='Discriminator Accuracy (Real)')
plt.plot(history['d_acc_fake'], label='Discriminator Accuracy (Fake)')
plt.title('Discriminator Accuracy Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# Plot losses
plt.figure(figsize=(8,5))
plt.plot(history['d_loss_real'], label='Discriminator Loss (Real)', color='blue')
plt.plot(history['d_loss_fake'], label='Discriminator Loss (Fake)', color='cyan')
plt.plot(history['g_loss'], label='Generator Loss', color='red')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('CGAN Training Loss')
plt.legend()
plt.grid(True)
plt.show()
